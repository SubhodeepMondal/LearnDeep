# %%
import numpy as np
from os.path import join

# %% [markdown]
# # Addition

# %% [markdown]
# ## Test_1

# %%
np.random.seed(42)
A_input_8_16 = np.random.rand(8, 16)
B_input_8_16 = np.random.rand(8, 16)
print(','.join(f'{x:.{8}f}' for x in A_input_16_16.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_input_16_16.flatten()))

# %%
addition_output_8_16 = np.add(A_input_8_16, B_input_8_16)
print(','.join(f'{x:.{8}f}' for x in addition_output_8_16.flatten()))

# %% [markdown]
# ## Test_2

# %%
np.random.seed(52)
A_add_input_31_19 = np.random.rand(31, 19)
B_add_input_31_19 = np.random.rand(31, 19)
print("Inputs:\n")
print(','.join(f'{x:.{8}f}' for x in A_add_input_31_19.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_add_input_31_19.flatten()))
addition_output_13_19 = np.add(A_add_input_31_19, B_add_input_31_19)
print("Output:\n")
print(','.join(f'{x:.{8}f}' for x in addition_output_13_19.flatten()))

# %% [markdown]
# ## Test_3

# %%
np.random.seed(67)
A_add_input_5_81_12 = np.random.rand(5, 81, 12)
B_add_input_5_81_12 = np.random.rand(5, 81, 12)
print("Inputs:\n")
print(','.join(f'{x:.{8}f}' for x in A_add_input_5_81_12.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_add_input_5_81_12.flatten()))
addition_output_5_81_12 = np.add(A_add_input_5_81_12, B_add_input_5_81_12)
print("Output:\n")
print(','.join(f'{x:.{8}f}' for x in addition_output_5_81_12.flatten()))

# %% [markdown]
# ## Test_4

# %%
np.random.seed(28)
A_add_input_5_6_13 = np.random.rand(5, 6, 13)
B_add_input_6_13 = np.random.rand(6, 13)
print("Inputs:\n")
print(','.join(f'{x:.{8}f}' for x in A_add_input_5_6_13.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_add_input_6_13.flatten()))
addition_output_5_6_13 = np.add(A_add_input_5_6_13, B_add_input_6_13)
print("Output:\n")
print(','.join(f'{x:.{8}f}' for x in addition_output_5_6_13.flatten()))

# %% [markdown]
# ## Test_5

# %%
np.random.seed(37)
A_add_input_4_3_5 = np.random.rand(4, 3, 5)
B_add_input_4_1_5 = np.random.rand(4, 1, 5)
print("Inputs:\n")
print(','.join(f'{x:.{8}f}' for x in A_add_input_4_3_5.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_add_input_4_1_5.flatten()))
addition_output_4_3_5 = np.add(A_add_input_4_3_5, B_add_input_4_1_5)
print("Output:\n")
print(','.join(f'{x:.{8}f}' for x in addition_output_4_3_5.flatten()))

# %% [markdown]
# ## Test_6

# %%
np.random.seed(41)
A_add_input_9_7_4_3_12 = np.random.rand(9 ,7,4, 3, 12)
B_add_input_9_1_1_3_1 = np.random.rand(9,1 ,1, 3, 1)
print("Inputs:")
print(','.join(f'{x:.{8}f}' for x in A_add_input_9_7_4_3_12.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_add_input_9_1_1_3_1.flatten()))
addition_output_9_7_4_3_12 = np.add(A_add_input_9_7_4_3_12, B_add_input_9_1_1_3_1)
print("Output:")
print(','.join(f'{x:.{8}f}' for x in addition_output_9_7_4_3_12.flatten()))

# %% [markdown]
# ### Test_7

# %%
np.random.seed(87)
A_add_input_64_56 = np.random.rand(64,56)
B_add_input_56 = np.random.rand(56)
print("Inputs:")
print(','.join(f'{x:.{8}f}' for x in A_add_input_64_56.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_add_input_56.flatten()))
addition_output_64_56 = np.add(A_add_input_64_56, B_add_input_56)
print("Output:")
print(','.join(f'{x:.{8}f}' for x in addition_output_64_56.flatten()))

# %% [markdown]
# ## Test_8

# %%
np.random.seed(91)
A_add_input_7_13 = np.random.rand(7, 13)
B_add_input_1 = np.random.rand(1)
print("Inputs:")
print(','.join(f'{x:.{8}f}' for x in A_add_input_7_13.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_add_input_1.flatten()))
addition_output_7_13 = np.add(A_add_input_7_13, B_add_input_1)
print("Output:")
print(','.join(f'{x:.{8}f}' for x in addition_output_7_13.flatten()))

# %% [markdown]
# ## Test_9

# %%
np.random.seed(63)
A_add_input_33_16 = np.random.rand(33, 16)
B_add_input_16 = np.random.rand(16)
E_add_input_33_16 = np.random.rand(33, 16)
print("Inputs:")

print(','.join(f'{x:.{8}f}' for x in A_add_input_33_16.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_add_input_16.flatten()))
print(','.join(f'{x:.{8}f}' for x in E_add_input_33_16.flatten()))


C_33_16 = np.add(A_add_input_33_16, B_add_input_16)
D_33_16 = np.multiply(C_33_16, E_add_input_33_16)
F_33_16 = np.multiply(C_33_16, D_33_16)

print("Outputs")
print(','.join(f'{x:.{8}f}' for x in F_33_16.flatten()))

dF = np.ones_like(F_33_16)              # upstream gradient

# F = C * D
dC_from_F = dF * D_33_16
dD = dF * C_33_16

# D = C * E
dC_from_D = dD * E_add_input_33_16
dE = dD * C_33_16

# total gradient for C
dC = dC_from_F + dC_from_D

# C = A + B
dA = dC
dB = np.sum(dC, axis=0)

print("Gradients")
print(','.join(f'{x:.{8}f}' for x in dA.flatten()))
print(','.join(f'{x:.{8}f}' for x in dB.flatten()))
print(','.join(f'{x:.{8}f}' for x in dC.flatten()))
print(','.join(f'{x:.{8}f}' for x in dD.flatten()))
print(','.join(f'{x:.{8}f}' for x in dE.flatten()))
print(','.join(f'{x:.{8}f}' for x in dF.flatten()))

# %% [markdown]
# ## Grad Pipeline

# %%
np.random.seed(63)
A_add_input_56_28 = np.random.rand(56,28)
B_add_input_56_28 = np.random.rand(56,28)
E_add_input_56_28 = np.random.rand(56,28)


print("Inputs:\n")
print(','.join(f'{x:.{8}f}' for x in A_add_input_56_28.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_add_input_56_28.flatten()))
print(','.join(f'{x:.{8}f}' for x in E_add_input_56_28.flatten()))

# %%
C_out_56_28 = np.add(A_add_input_56_28, B_add_input_56_28)
D_out_56_28 = np.multiply(C_out_56_28, E_add_input_56_28)
F_out_56_28 = np.multiply(C_out_56_28, D_out_56_28)

print(','.join(f'{x:.{8}f}' for x in F_out_56_28.flatten()))

# %%
delta_F = np.ones((56,28),np.float64)
delta_E = C_out_56_28 * C_out_56_28
delta_D = C_out_56_28
delta_C = D_out_56_28 + C_out_56_28 * E_add_input_56_28
delta_B = delta_C
delta_A = delta_C


print("Output:\n")
print(','.join(f'{x:.{8}f}' for x in delta_E.flatten()))
print(','.join(f'{x:.{8}f}' for x in delta_D.flatten()))
print(','.join(f'{x:.{8}f}' for x in delta_C.flatten()))
print(','.join(f'{x:.{8}f}' for x in delta_B.flatten()))
print(','.join(f'{x:.{8}f}' for x in delta_A.flatten()))

# %% [markdown]
# # subtraction

# %% [markdown]
# ## Test 1

# %%
np.random.seed(42)
A_input_15_17 = 5 * np.random.rand(15,17)
B_input_15_17 = 3 * np.random.rand(15,17)
print(','.join(f'{x:.{8}f}' for x in A_input_15_17.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_input_15_17.flatten()))

output_15_17 = np.subtract(A_input_15_17, B_input_15_17)
print(','.join(f'{x:.{8}f}' for x in output_15_17.flatten()))

# %% [markdown]
# ## Test 2

# %%
np.random.seed(21)
A_input_3_5_7_13 = 5 * np.random.rand(3, 5, 7, 13)
B_input_3_5_7_13 = 3 * np.random.rand(3, 5, 7, 13)
print("Inputs")
print(','.join(f'{x:.{8}f}' for x in A_input_3_5_7_13.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_input_3_5_7_13.flatten()))

output_3_5_7_13 = np.subtract(A_input_3_5_7_13, B_input_3_5_7_13)
print("Output")
print(','.join(f'{x:.{8}f}' for x in output_3_5_7_13.flatten()))

# %% [markdown]
# ## Test 3

# %%
np.random.seed(13)
A_input_6_7_16 = 7 * np.random.rand(6, 7, 16)
B_input_6_1_16 = 5 * np.random.rand(6, 1, 16)
print("Inputs")
print(','.join(f'{x:.{8}f}' for x in A_input_6_7_16.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_input_6_1_16.flatten()))

output_6_7_16 = np.subtract(A_input_6_7_16, B_input_6_1_16)
print("Output")
print(','.join(f'{x:.{8}f}' for x in output_6_7_16.flatten()))

# %% [markdown]
# ## Test 4

# %%
np.random.seed(31)
A_input_19_18 = 3 * np.random.rand( 19, 18)
B_input_1_18 = 4 * np.random.rand( 1, 18)
print("Inputs")
print(','.join(f'{x:.{8}f}' for x in A_input_19_18.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_input_1_18.flatten()))

output_19_18 = np.subtract(A_input_19_18, B_input_1_18)
print("Output")
print(','.join(f'{x:.{8}f}' for x in output_19_18.flatten()))

# %% [markdown]
# ## Test 5

# %%
# don't run this test unless necessary! It bloats the computer
np.random.seed(13)
A_input_5_6_7_10_12 = 3 * np.random.rand( 5, 6, 7, 10, 12)
B_input_6_1_10_1 = 4 * np.random.rand( 6, 1, 10, 1)
print("Inputs")
print(','.join(f'{x:.{8}f}' for x in A_input_5_6_7_10_12.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_input_6_1_10_1.flatten()))

output_5_6_7_10_12 = np.subtract(A_input_5_6_7_10_12, B_input_6_1_10_1)
print("Output")
print(','.join(f'{x:.{8}f}' for x in output_5_6_7_10_12.flatten()))

# %% [markdown]
# ## Test 6

# %%
np.random.seed(19)
A_input_5_32_38 = 3 * np.random.rand( 5, 32, 38)
B_input_5_1_38 = 4 * np.random.rand( 5, 1, 38)
print("Inputs")
print(','.join(f'{x:.{8}f}' for x in A_input_5_32_38.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_input_5_1_38.flatten()))

output_5_32_38 = np.subtract(A_input_5_32_38, B_input_5_1_38)
print("Output")
print(','.join(f'{x:.{8}f}' for x in output_5_32_38.flatten()))

# %% [markdown]
# ## Test 7

# %%
np.random.seed(19)
A_input_32_42 = 3 * np.random.rand(32, 42)
B_input_42 = 4 * np.random.rand( 42)
E_input_42_72 = 2 * np.random.rand(42, 72)
F_input_32_42 = 5 * np.random.rand(32, 42)
print("Inputs")
print(','.join(f'{x:.{8}f}' for x in A_input_32_42.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_input_42.flatten()))
print(','.join(f'{x:.{8}f}' for x in E_input_42_72.flatten()))
print(','.join(f'{x:.{8}f}' for x in F_input_32_42.flatten()))

C_32_42 = np.subtract(A_input_32_42, B_input_42)
D_32_42 = np.multiply(F_input_32_42, C_32_42)
G_32_72 = np.matmul(C_32_42, E_input_42_72)

print("Output")
print(','.join(f'{x:.{8}f}' for x in C_32_42.flatten()))
print(','.join(f'{x:.{8}f}' for x in D_32_42.flatten()))
print(','.join(f'{x:.{8}f}' for x in G_32_72.flatten()))

# gradient calculation
# ----- backward -----
dD = np.ones_like(D_32_42)          # ∂L/∂D
dG = np.ones_like(G_32_72)          # ∂L/∂G

# ---- D = F * C ----
dF = dD * C_32_42
dC_from_D = dD * F_input_32_42

# ---- G = C @ E ----
dC_from_G = dG @ E_input_42_72.T          # (32,72) @ (72,42)
dE = C_32_42.T @ dG                 # (42,32) @ (32,72)

# ---- accumulate gradients for C ----
dC = dC_from_D + dC_from_G

# ---- C = A - B ----
dA = dC
dB = -np.sum(dC, axis=0)      # reduce broadcast axis

print("Gradients")
print(','.join(f'{x:.{8}f}' for x in dA.flatten()))
print(','.join(f'{x:.{8}f}' for x in dB.flatten()))
print(','.join(f'{x:.{8}f}' for x in dC.flatten()))
print(','.join(f'{x:.{8}f}' for x in dE.flatten()))
print(','.join(f'{x:.{8}f}' for x in dF.flatten()))

# %% [markdown]
# # Haramand Multiply

# %%
np.random.seed(33)
A_mul_input_16_64 = np.random.rand(16,64)
B_mul_input_16_64 = np.random.rand(16,64)
print(','.join(f'{x:.{8}f}' for x in A_mul_input_16_64.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_mul_input_16_64.flatten()))

# %%
mul_output_16_64 = np.multiply(A_mul_input_16_64, B_mul_input_16_64)
print(','.join(f'{x:.{8}f}' for x in mul_output_16_64.flatten()))

# %%
A_mul_input_41_27 = np.random.rand(41,27)
B_mul_input_41_27 = np.random.rand(41,27)
print(','.join(f'{x:.{8}f}' for x in A_mul_input_41_27.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_mul_input_41_27.flatten()))

# %%
mul_output_41_27 = np.multiply(A_mul_input_41_27, B_mul_input_41_27)
print(','.join(f'{x:.{8}f}' for x in mul_output_41_27.flatten()))

# %% [markdown]
# # Division

# %% [markdown]
# ## Test 1

# %%
import numpy as np
np.random.seed(33)
A = np.random.rand(11,32)
B = np.random.rand(11,32)
C = (A/B)
print(','.join(f'{x:.{8}f}' for x in A.flatten()))
print(','.join(f'{x:.{8}f}' for x in B.flatten()))
print(','.join(f'{x:.{8}f}' for x in C.flatten()))

A.astype(A.astype(np.float64).tofile("../data/MatrixDiv_Test_1_input.bin"))
B.astype(B.astype(np.float64).tofile("../data/MatrixDiv_Test_1_input_b.bin"))
C.astype(C.astype(np.float64).tofile("../data/MatrixDiv_Test_1_output.bin"))
# Out:
# 0.24851013,0.44997542,0.41094080,0.26029969,0.87039569,0.18503993,0.01966143,0.95325203,0.68045080,0.48658813,0.96502682,0.39339874,0.07955757,0.35140742,0.16363516,0.98316682,0.88062818,0.49406347,0.40095924,0.45129146,0.72087685,0.24776828,0.62277995,0.14244882,0.20117628,0.08121773,0.95347229,0.05573827,0.59953648,0.72299763,0.97028972,0.82156946,0.52755107,0.33147673,0.35398220,0.07903030,0.55591438,0.16579446,0.29523783,0.84060849,0.36256201,0.34081398,0.71040174,0.03170775,0.47238787,0.73157662,0.77321577,0.24124479,0.30619705,0.13664964,0.59573572,0.16256887,0.80232721,0.50012665,0.05949433,0.39186578,0.61977550,0.18819184,0.42788848,0.08898164,0.73263044,0.39329936,0.34413639,0.39688474,0.01737203,0.46836500,0.89325052,0.16156441,0.84445946,0.27506830,0.76873253,0.83400262,0.90129632,0.97182492,0.42903617,0.68608431,0.32627748,0.79748919,0.43452837,0.51019439,0.76332864,0.17391915,0.45244554,0.89819137,0.68928312,0.28597000,0.42086349,0.56792075,0.96763159,0.56071049,0.972864
# ...

# %% [markdown]
# ## Test 2

# %%
import numpy as np
np.random.seed(33)
A = np.random.rand(11,32,13, 37)
B = np.random.rand(11,32, 1, 37 )
C = (A/B)
print(','.join(f'{x:.{8}f}' for x in A.flatten()))
print(','.join(f'{x:.{8}f}' for x in B.flatten()))
print(','.join(f'{x:.{8}f}' for x in C.flatten()))

A.astype(A.astype(np.float64).tofile("../data/MatrixDiv_Test_2_input.bin"))
B.astype(B.astype(np.float64).tofile("../data/MatrixDiv_Test_2_input_b.bin"))
C.astype(C.astype(np.float64).tofile("../data/MatrixDiv_Test_2_output.bin"))
# Out:
# 0.24851013,0.44997542,0.41094080,0.26029969,0.87039569,0.18503993,0.01966143,0.95325203,0.68045080,0.48658813,0.96502682,0.39339874,0.07955757,0.35140742,0.16363516,0.98316682,0.88062818,0.49406347,0.40095924,0.45129146,0.72087685,0.24776828,0.62277995,0.14244882,0.20117628,0.08121773,0.95347229,0.05573827,0.59953648,0.72299763,0.97028972,0.82156946,0.52755107,0.33147673,0.35398220,0.07903030,0.55591438,0.16579446,0.29523783,0.84060849,0.36256201,0.34081398,0.71040174,0.03170775,0.47238787,0.73157662,0.77321577,0.24124479,0.30619705,0.13664964,0.59573572,0.16256887,0.80232721,0.50012665,0.05949433,0.39186578,0.61977550,0.18819184,0.42788848,0.08898164,0.73263044,0.39329936,0.34413639,0.39688474,0.01737203,0.46836500,0.89325052,0.16156441,0.84445946,0.27506830,0.76873253,0.83400262,0.90129632,0.97182492,0.42903617,0.68608431,0.32627748,0.79748919,0.43452837,0.51019439,0.76332864,0.17391915,0.45244554,0.89819137,0.68928312,0.28597000,0.42086349,0.56792075,0.96763159,0.56071049,0.972864
# ...

# %% [markdown]
# # Matrix Multiplication

# %%
np.random.seed(42)
A_matmul_inp_16_32 = np.random.rand(16,32)
B_matmul_inp_32_16 = np.random.rand(32,16)

print(','.join(f'{x:.{8}f}' for x in A_matmul_inp_16_32.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_matmul_inp_32_16.flatten()))

# %%
matmul_out_16_16 = np.matmul(A_matmul_inp_16_32, B_matmul_inp_32_16)
print(matmul_out_16_16.shape[0])
print(matmul_out_16_16.shape[1])
print(','.join(f'{x:.{8}f}' for x in matmul_out_16_16.flatten()))

# %% [markdown]
# ####Grad

# %%
incoming_grad = np.ones((16,16),np.float64)
A_input_16_32_grad = np.matmul(incoming_grad, B_matmul_inp_32_16.T)
B_input_32_16_grad = np.matmul(A_matmul_inp_16_32.T, incoming_grad);
print(','.join(f'{x:.{8}f}' for x in A_input_16_32_grad.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_input_32_16_grad.flatten()))

# %% [markdown]
# ####Gradient Pipeline

# %%
np.random.seed(42)
C_mul_inp_16_16 = np.random.rand(16,16)
print(','.join(f'{x:.{8}f}' for x in C_mul_inp_16_16.flatten()))

# %%
pow_out = np.power(matmul_out_16_16, 2)
print(','.join(f'{x:.{8}f}' for x in pow_out.flatten()))

# %%
mul_out_16_16 = np.multiply(matmul_out_16_16, C_mul_inp_16_16)
print(','.join(f'{x:.{8}f}' for x in mul_out_16_16.flatten()))

# %%
delta_pow = 2 * matmul_out_16_16
delta_mul = C_mul_inp_16_16
delta_A = np.matmul(np.add(delta_pow, delta_mul), B_matmul_inp_32_16.T)
delta_B = np.matmul(A_matmul_inp_16_32.T, np.add(delta_pow, delta_mul))
print(','.join(f'{x:.{8}f}' for x in delta_A.flatten()))
print(','.join(f'{x:.{8}f}' for x in delta_B.flatten()))

# %% [markdown]
# ####37_75 75_37 37_46

# %%
np.random.seed(42)
A_matmul_inp_37_75 = np.random.rand(37,75)
B_matmul_inp_75_46 = np.random.rand(75,46)

print(','.join(f'{x:.{8}f}' for x in A_matmul_inp_37_75.flatten()))
print(','.join(f'{x:.{8}f}' for x in B_matmul_inp_75_46.flatten()))

# %%
matmul_out_37_46 = np.matmul(A_matmul_inp_37_75, B_matmul_inp_75_46)
print(matmul_out_37_46.shape[0])
print(matmul_out_37_46.shape[1])
print(','.join(f'{x:.{8}f}' for x in matmul_out_37_46.flatten()))

# %% [markdown]
# # Scale

# %% [markdown]
# ## Grad Scale test 1

# %%
import numpy as np

np.random.seed(73)

# ------------------------------------------------------------
# Inputs
# ------------------------------------------------------------

A = np.random.randn(8, 12).astype(np.float64)
C = np.random.randn(8, 12).astype(np.float64)

# ------------------------------------------------------------
# Forward
# ------------------------------------------------------------

B = A * 2.78
D = C * B
E = B ** 3

# ------------------------------------------------------------
# Loss
# L = sum(D) + sum(E)
# ------------------------------------------------------------

loss = np.sum(D) + np.sum(E)

# ------------------------------------------------------------
# Backward
#
# dL/dD = 1
# dL/dE = 1
#
# D = C * B
# E = B^3
#
# dL/dB = C + 3 * B^2
# dL/dC = B
# dL/dA = dL/dB * 2.78
# ------------------------------------------------------------

grad_D = np.ones_like(D)
grad_E = np.ones_like(E)

grad_B_from_D = grad_D * C
grad_B_from_E = grad_E * 3.0 * (B ** 2)

grad_B = grad_B_from_D + grad_B_from_E

grad_A = grad_B * 2.78
grad_C = grad_D * B

# ------------------------------------------------------------
# Save tensors
# ------------------------------------------------------------

A.astype(np.float64).tofile("../data/ScaleMulPow_Test_1_A.bin")
C.astype(np.float64).tofile("../data/ScaleMulPow_Test_1_C.bin")

B.astype(np.float64).tofile("../data/ScaleMulPow_Test_1_B.bin")
D.astype(np.float64).tofile("../data/ScaleMulPow_Test_1_D.bin")
E.astype(np.float64).tofile("../data/ScaleMulPow_Test_1_E.bin")

# ------------------------------------------------------------
# Save intercepted gradients
# ------------------------------------------------------------

grad_A.astype(np.float64).tofile("../data/ScaleMulPow_Test_1_grad_A.bin")
grad_B.astype(np.float64).tofile("../data/ScaleMulPow_Test_1_grad_B.bin")
grad_C.astype(np.float64).tofile("../data/ScaleMulPow_Test_1_grad_C.bin")
grad_D.astype(np.float64).tofile("../data/ScaleMulPow_Test_1_grad_D.bin")
grad_E.astype(np.float64).tofile("../data/ScaleMulPow_Test_1_grad_E.bin")

print("Loss:", loss)

print("\nShapes:")
print("A:", A.shape)
print("B:", B.shape)
print("C:", C.shape)
print("D:", D.shape)
print("E:", E.shape)

print("\nGradient shapes:")
print("grad_A:", grad_A.shape)
print("grad_B:", grad_B.shape)
print("grad_C:", grad_C.shape)
print("grad_D:", grad_D.shape)
print("grad_E:", grad_E.shape)
# Out:
# Loss: 247.4237917589465
#
# Shapes:
# A: (8, 12)
# B: (8, 12)
# C: (8, 12)
# D: (8, 12)
# E: (8, 12)
#
# Gradient shapes:
# grad_A: (8, 12)
# grad_B: (8, 12)
# grad_C: (8, 12)
# grad_D: (8, 12)
# grad_E: (8, 12)

# %% [markdown]
# # Mean

# %% [markdown]
# ## Test 1

# %%
import numpy as np
np.random.seed(13)

A_67_11 = np.random.rand(67, 11)
C_11 = np.mean(A_67_11, axis=0)

A_67_11.astype(A_67_11.astype(np.float64).tofile("../data/MatrixMean_Test_1_input.bin"))
C_11.astype(C_11.astype(np.float64).tofile("../data/MatrixMean_Test_1_output.bin"))
# Out:
# array([0.52043546, 0.4548511 , 0.50544822, 0.457339  , 0.51985094,
#        0.48226937, 0.45909266, 0.49210502, 0.42760288, 0.49568209,
#        0.4821614 ])

# %% [markdown]
# ## Test 2

# %%
import numpy as np
np.random.seed(17)

A_37_11_20_8 = np.random.rand(37,11,20,8)
C_37_20_8 = np.mean(A_37_11_20_8, axis=2)


A_37_11_20_8.astype(A_37_11_20_8.astype(np.float64).tofile("../data/MatrixMean_Test_2_input.bin"))
C_37_20_8.astype(C_37_20_8.astype(np.float64).tofile("../data/MatrixMean_Test_2_output.bin"))
# Out:
# array([[[0.51847023, 0.49440683, 0.55826414, ..., 0.64188039,
#          0.41005075, 0.52756042],
#         [0.46357245, 0.58151598, 0.59309749, ..., 0.61533053,
#          0.59811764, 0.46822309],
#         [0.52511749, 0.4486401 , 0.48070133, ..., 0.4752619 ,
#          0.46626587, 0.55263666],
#         ...,
#         [0.520679  , 0.43648527, 0.44640656, ..., 0.43414254,
#          0.4722135 , 0.59812939],
#         [0.51235628, 0.42418252, 0.4730761 , ..., 0.44017239,
#          0.56408338, 0.49276295],
#         [0.56358368, 0.40329888, 0.48434318, ..., 0.43596832,
#          0.45859945, 0.48421478]],
#
#        [[0.54629072, 0.53437037, 0.48823538, ..., 0.66399698,
#          0.56556645, 0.54278608],
#         [0.47679371, 0.50457929, 0.45041317, ..., 0.58453839,
#          0.50425854, 0.48430947],
#         [0.51823355, 0.50503861, 0.44084724, ..., 0.50975197,
#          0.43227331, 0.63978333],
#         ...,
#         [0.54613251, 0.40743682, 0.47924682, ..., 0.44805809,
# ...

# %%
pow = np.power(a, 2)
print(pow)

# %%
print(np.mean(a, axis=0))

# %% [markdown]
# # Power

# %%
power_b = np.power(a, 2)
power_c = np.power(power_b, 3)
print(','.join(f'{x:.{8}f}' for x in power_b.flatten()))
print(','.join(f'{x:.{8}f}' for x in power_c.flatten()))

# %%
power_b = np.power(a, 2)
power_c = np.power(power_b, 3)
print(','.join(f'{x:.{8}f}' for x in power_b.flatten()))
print(','.join(f'{x:.{8}f}' for x in power_c.flatten()))

# %%
print(np.subtract(a,b))

# %%
print(np.array2string(b, separator=', '))

# %%
print(np.array2string(np.sqrt(a), separator=', '))

# %%
print(np.array2string(np.subtract(a,0.5), separator=', '))
print(np.array2string(np.maximum(0,np.subtract(a,0.5)), separator=', '))

# %% [markdown]
# # Natural Log

# %%
import numpy as np

# Test 1
a_1 = np.random.rand(67, 18)
c_1 = np.log(a_1)


print(','.join(f'{x:.{8}f}' for x in a_1.flatten()))
print(','.join(f'{x:.{8}f}' for x in c_1.flatten()))

a_1.astype(a_1.astype(np.float64).tofile("../data/MatrixLog_Test_1_input.bin"))
c_1.astype(c_1.astype(np.float64).tofile("../data/MatrixLog_Test_1_output.bin"))


# Test 2
a_2 = np.random.rand(9, 8, 10, 21, 13)
c_2 = np.log(a_2)


print(','.join(f'{x:.{8}f}' for x in a_2.flatten()))
print(','.join(f'{x:.{8}f}' for x in c_2.flatten()))

a_2.astype(a_2.astype(np.float64).tofile("../data/MatrixLog_Test_2_input.bin"))
c_2.astype(c_2.astype(np.float64).tofile("../data/MatrixLog_Test_2_output.bin"))
# Out:
# 0.04748266,0.21820688,0.60508671,0.47523523,0.74891321,0.73153961,0.18344577,0.31609704,0.59463921,0.47442225,0.15138928,0.01949200,0.06850514,0.81954172,0.96688296,0.66023104,0.03685427,0.53034669,0.27561206,0.14623194,0.11149022,0.07471608,0.35893009,0.58768149,0.32487527,0.38705604,0.52032077,0.51776933,0.48249850,0.94400956,0.82984206,0.07261283,0.45077558,0.67344647,0.08098335,0.23637508,0.77443264,0.74699835,0.39521424,0.11790987,0.50764507,0.71719142,0.64472820,0.43545879,0.51789554,0.35827624,0.82271758,0.90999578,0.55932673,0.01411438,0.42032478,0.89729636,0.03692841,0.02418847,0.66527672,0.22191700,0.15779097,0.60165412,0.06547164,0.39109414,0.47250216,0.24867906,0.11061613,0.10857880,0.59688166,0.93184936,0.11472046,0.76698717,0.28320506,0.53115140,0.61242499,0.53342427,0.70842728,0.33280749,0.55489600,0.75367554,0.03205002,0.33207516,0.97186789,0.53502720,0.62277858,0.27056832,0.89945540,0.18820441,0.68469975,0.23659060,0.85313305,0.83843494,0.24618282,0.66934444,0.274980
# ...

# %% [markdown]
# ## autograd test

# %%
import numpy as np

np.random.seed(73)

# ============================================================
# Test 1: Standalone natural log autograd
#
# A [56,83]
# B = log(A)
# L = sum(B)
# dA = 1 / A
# ============================================================

log_A1 = np.random.rand(56, 83) + 0.25
log_B1 = np.log(log_A1)
log_A1_grad = 1.0 / log_A1

log_A1.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_1_A.bin")
log_B1.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_1_B.bin")
log_A1_grad.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_1_A_grad.bin")


# ============================================================
# Test 2: Natural log propagation + gradient accumulation
#
# A [26,45]
# B = log(A)
# D [45,13]
# C = B @ D
# E [26,45]
# F = B * E
# L = sum(C) + sum(F)
# ============================================================

log_A2 = np.random.rand(26, 45) + 0.25
log_D2 = np.random.rand(45, 13) - 0.5
log_E2 = np.random.rand(26, 45) - 0.5

log_B2 = np.log(log_A2)
log_C2 = np.matmul(log_B2, log_D2)
log_F2 = log_B2 * log_E2

log_dC2 = np.ones_like(log_C2)
log_dF2 = np.ones_like(log_F2)

log_dB2_from_C = np.matmul(log_dC2, log_D2.T)
log_D2_grad = np.matmul(log_B2.T, log_dC2)
log_dB2_from_F = log_dF2 * log_E2
log_E2_grad = log_dF2 * log_B2
log_dB2 = log_dB2_from_C + log_dB2_from_F
log_A2_grad = log_dB2 / log_A2

log_A2.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_2_A.bin")
log_B2.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_2_B.bin")
log_D2.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_2_D.bin")
log_C2.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_2_C.bin")
log_E2.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_2_E.bin")
log_F2.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_2_F.bin")
log_A2_grad.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_2_A_grad.bin")
log_D2_grad.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_2_D_grad.bin")
log_E2_grad.astype(np.float64).tofile("../data/MatrixLog_Autograd_Test_2_E_grad.bin")

# %% [markdown]
# # Sigmoid

# %%
def sigmoid(x):
  """
  Computes the sigmoid function for a given input x.

  Args:
    x: A single number or a NumPy array.

  Returns:
    The sigmoid of x, a value or a NumPy array with values between 0 and 1.
  """
  return 1 / (1 + np.exp(-x))

# Example usage with a NumPy array
# array = np.array([-2, 0, 2])
sigmoid_array = sigmoid(a)
flat_elem = [str(item) for item in sigmoid_array.flatten()]

print(','.join(f'{x:.{8}f}' for x in sigmoid_array.flatten()))

# %%
a_grad = 2 * a * b_grad
print(','.join(f'{x:.{8}f}' for x in a_grad.flatten()))

# %%
c = np.add(a,b);
e = pow
d =np.multiply(c,e);
f = np.multiply(c,d);

print(','.join(f'{x:.{8}f}' for x in f.flatten()))

# %%
d_d = c
print(','.join(f'{x:.{8}f}' for x in d_d.flatten()))

# %%
d_e = np.multiply(d_d, c)
print(','.join(f'{x:.{8}f}' for x in d_e.flatten()))

# %%
d_t0 = d
d_t1 = c
d_c_2 = np.multiply(e, d_t0)
d_c_3 = np.multiply(e, d_t1)
d_c = 2 * np.multiply(e, c)
print(','.join(f'{x:.{8}f}' for x in d_c.flatten()))

# %% [markdown]
# # Softmax

# %% [markdown]
# ### Softmax forward prop tests

# %%
def softmax(x, axis):
    x_shifted = x - np.max(x, axis=axis, keepdims=True)
    exp_x = np.exp(x_shifted)
    return exp_x / np.sum(exp_x, axis=axis, keepdims=True)


np.random.seed(42)

# Test 1: 2D tensor of size 167, 544; softmax on axis 0
softmax_input_167_544 = np.random.rand(167, 544)
softmax_output_167_544_axis_0 = softmax(softmax_input_167_544, axis=0)
softmax_input_167_544.astype(np.float64).tofile("../data/Softmax_Test_1_input.bin")
softmax_output_167_544_axis_0.astype(np.float64).tofile("../data/Softmax_Test_1_output.bin")

# Test 2: 3D tensor of size 78, 37, 19; softmax on axis 1
softmax_input_78_37_19 = np.random.rand(78, 37, 19)
softmax_output_78_37_19_axis_1 = softmax(softmax_input_78_37_19, axis=1)
softmax_input_78_37_19.astype(np.float64).tofile("../data/Softmax_Test_2_input.bin")
softmax_output_78_37_19_axis_1.astype(np.float64).tofile("../data/Softmax_Test_2_output.bin")

# Test 3: n-dim tensor of size 7, 11, 112, 5, 6; softmax on axis 4
softmax_input_7_11_112_5_6 = np.random.rand(7, 11, 112, 5, 6)
softmax_output_7_11_112_5_6_axis_4 = softmax(softmax_input_7_11_112_5_6, axis=4)
softmax_input_7_11_112_5_6.astype(np.float64).tofile("../data/Softmax_Test_3_input.bin")
softmax_output_7_11_112_5_6_axis_4.astype(np.float64).tofile("../data/Softmax_Test_3_output.bin")

# Test 4: 1D tensor of size 8000; softmax on axis 0
softmax_input_8000 = np.random.rand(8000)
softmax_output_8000_axis_0 = softmax(softmax_input_8000, axis=0)
softmax_input_8000.astype(np.float64).tofile("../data/Softmax_Test_4_input.bin")
softmax_output_8000_axis_0.astype(np.float64).tofile("../data/Softmax_Test_4_output.bin")

# Test 5: 1D tensor of size 16000; softmax on axis 0
softmax_input_16000 = np.random.rand(16000)
softmax_output_16000_axis_0 = softmax(softmax_input_16000, axis=0)
softmax_input_16000.astype(np.float64).tofile("../data/Softmax_Test_5_input.bin")
softmax_output_16000_axis_0.astype(np.float64).tofile("../data/Softmax_Test_5_output.bin")

# Test 6: 2D tensor of size 8000, 2; softmax on axis 0
softmax_input_8000_2 = np.random.rand(8000, 2)
softmax_output_8000_2_axis_0 = softmax(softmax_input_8000_2, axis=0)
softmax_input_8000_2.astype(np.float64).tofile("../data/Softmax_Test_6_input.bin")
softmax_output_8000_2_axis_0.astype(np.float64).tofile("../data/Softmax_Test_6_output.bin")

# Test 7: 2D tensor of size 2, 8000; softmax on axis 1
softmax_input_2_8000 = np.random.rand(2, 8000)
softmax_output_2_8000_axis_1 = softmax(softmax_input_2_8000, axis=1)
softmax_input_2_8000.astype(np.float64).tofile("../data/Softmax_Test_7_input.bin")
softmax_output_2_8000_axis_1.astype(np.float64).tofile("../data/Softmax_Test_7_output.bin")

# Test 8: 1D tensor of size 13; softmax on axis 0
softmax_input_13 = np.random.rand(13)
softmax_output_13_axis_0 = softmax(softmax_input_13, axis=0)
softmax_input_13.astype(np.float64).tofile("../data/Softmax_Test_8_input.bin")
softmax_output_13_axis_0.astype(np.float64).tofile("../data/Softmax_Test_8_output.bin")

# Test 9: 1D tensor of size 180; softmax on axis 0
softmax_input_180 = np.random.rand(180)
softmax_output_180_axis_0 = softmax(softmax_input_180, axis=0)
softmax_input_180.astype(np.float64).tofile("../data/Softmax_Test_9_input.bin")
softmax_output_180_axis_0.astype(np.float64).tofile("../data/Softmax_Test_9_output.bin")

# Test 10: 2D tensor of size 13, 43; softmax on axis 0
softmax_input_13_43 = np.random.rand(13, 43)
softmax_output_13_43_axis_0 = softmax(softmax_input_13_43, axis=0)
softmax_input_13_43.astype(np.float64).tofile("../data/Softmax_Test_10_input.bin")
softmax_output_13_43_axis_0.astype(np.float64).tofile("../data/Softmax_Test_10_output.bin")

# Test 11: 2D tensor of size 43, 13; softmax on axis 1
softmax_input_43_13 = np.random.rand(43, 13)
softmax_output_43_13_axis_1 = softmax(softmax_input_43_13, axis=1)
softmax_input_43_13.astype(np.float64).tofile("../data/Softmax_Test_11_input.bin")
softmax_output_43_13_axis_1.astype(np.float64).tofile("../data/Softmax_Test_11_output.bin")

# Test 12: 3D tensor of size 13, 180, 43; softmax on axis 1
softmax_input_13_180_43 = np.random.rand(13, 180, 43)
softmax_output_13_180_43_axis_1 = softmax(softmax_input_13_180_43, axis=1)
softmax_input_13_180_43.astype(np.float64).tofile("../data/Softmax_Test_12_input.bin")
softmax_output_13_180_43_axis_1.astype(np.float64).tofile("../data/Softmax_Test_12_output.bin")

# Test 13: 3D tensor of size 13, 43, 180; softmax on axis 2
softmax_input_13_43_180 = np.random.rand(13, 43, 180)
softmax_output_13_43_180_axis_2 = softmax(softmax_input_13_43_180, axis=2)
softmax_input_13_43_180.astype(np.float64).tofile("../data/Softmax_Test_13_input.bin")
softmax_output_13_43_180_axis_2.astype(np.float64).tofile("../data/Softmax_Test_13_output.bin")

# %% [markdown]
# ### Softmax gradient Test 1

# %%
import numpy as np

np.random.seed(13)


def softmax(x, axis):
    x_max = np.max(x, axis=axis, keepdims=True)
    exp_x = np.exp(x - x_max)
    return exp_x / np.sum(exp_x, axis=axis, keepdims=True)


# ============================================================
# Test 1: Standalone Softmax autograd
#
# Framework:
#
# A [52,162]
# B = softmax(A, axis=0)
#
# Framework axis 0 -> NumPy axis 1
#
# Therefore NumPy:
#
# A [162,52]
# B [162,52]
# ============================================================

softmax_A = np.random.rand(162, 52)

softmax_B = softmax(softmax_A, axis=1)

# Artificial incoming gradient dL/dB
softmax_dB = np.random.rand(162, 52) - 0.5

# Softmax backward:
#
# dA = B * (
#          dB -
#          sum(B * dB, axis=1, keepdims=True)
#      )

softmax_dA = (
    softmax_B
    * (
        softmax_dB
        - np.sum(
            softmax_B * softmax_dB,
            axis=1,
            keepdims=True
        )
    )
)

# ------------------------------------------------------------
# Write data
# ------------------------------------------------------------

softmax_A.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_1_input.bin"
)

softmax_B.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_1_output.bin"
)

softmax_dB.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_1_incoming_gradient.bin"
)

softmax_dA.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_1_expected_gradient.bin"
)

# %% [markdown]
# ### Softmax gradient Test 2

# %%
import numpy as np

np.random.seed(55)


def softmax(x, axis):
    x_max = np.max(x, axis=axis, keepdims=True)
    exp_x = np.exp(x - x_max)
    return exp_x / np.sum(exp_x, axis=axis, keepdims=True)
# ============================================================
# Test 2: Softmax propagation + gradient accumulation
#
# Framework:
#
# A [13,17]
# B = softmax(A, axis=1)
#
# C [72,13]
# E = B @ C
#
# D [13,17]
# F = B + D
#
# L = sum(E) + sum(F)
#
#
# NumPy representation:
#
# A [17,13]
# B [17,13]
# C [13,72]
# E [17,72]
# D [17,13]
# F [17,13]
# ============================================================

prop_A = np.random.rand(17, 13)
prop_C = np.random.rand(13, 72)
prop_D = np.random.rand(17, 13)

# ------------------------------------------------------------
# Forward
# ------------------------------------------------------------

# Framework axis=1 -> NumPy axis=0
prop_B = softmax(prop_A, axis=0)

prop_E = np.matmul(prop_B, prop_C)
prop_F = prop_B + prop_D


# ============================================================
# Backward
# ============================================================

# L = sum(E) + sum(F)

prop_dE = np.ones_like(prop_E)
prop_dF = np.ones_like(prop_F)


# ------------------------------------------------------------
# E = B @ C
# ------------------------------------------------------------

# NumPy:
#
# E = B C
#
# dB = dE C^T
# dC = B^T dE

prop_dB_from_E = np.matmul(
    prop_dE,
    prop_C.T
)

prop_dC = np.matmul(
    prop_B.T,
    prop_dE
)


# ------------------------------------------------------------
# F = B + D
# ------------------------------------------------------------

prop_dB_from_F = prop_dF
prop_dD = prop_dF


# ------------------------------------------------------------
# Gradient accumulation at B
# ------------------------------------------------------------

prop_dB = (
    prop_dB_from_E
    + prop_dB_from_F
)


# ------------------------------------------------------------
# B = Softmax(A, axis=0)
#
# Framework axis=1 -> NumPy axis=0
# ------------------------------------------------------------

prop_dA = (
    prop_B
    * (
        prop_dB
        - np.sum(
            prop_B * prop_dB,
            axis=0,
            keepdims=True
        )
    )
)


# ============================================================
# Write data
# ============================================================

prop_A.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_2_A.bin"
)

prop_C.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_2_C.bin"
)

prop_D.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_2_D.bin"
)

prop_B.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_2_B.bin"
)

prop_E.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_2_E.bin"
)

prop_F.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_2_F.bin"
)

prop_dA.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_2_A_grad.bin"
)

prop_dC.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_2_C_grad.bin"
)

prop_dD.astype(np.float64).tofile(
    "../data/Softmax_Autograd_Test_2_D_grad.bin"
)

# %% [markdown]
# ## Softmax Layer Test

# %%
import numpy as np


def softmax(x, axis):
    x_shifted = x - np.max(x, axis=axis, keepdims=True)
    exp_x = np.exp(x_shifted)
    return exp_x / np.sum(exp_x, axis=axis, keepdims=True)


np.random.seed(42)

# Test 1:
# forward:
#   Dense(56)
#   Softmax()
#
# Batch size: 128
# Epochs: 100
# Forward pass only

batch_size = 128
input_features = 128
dense_features = 56
epochs = 1

# Generate input for one batch
softmax_input = np.random.rand(batch_size, input_features)

# Dense layer parameters
dense_weights = np.random.rand(input_features, dense_features)
dense_bias = np.random.rand(dense_features)

# Save input
softmax_input.astype(np.float64).tofile(
    "../data/SoftmaxLayer_Test_1_input.bin"
)

# Save Dense parameters
dense_weights.astype(np.float64).tofile(
    "../data/SoftmaxLayer_Test_1_weights.bin"
)

dense_bias.astype(np.float64).tofile(
    "../data/SoftmaxLayer_Test_1_bias.bin"
)

# Reference forward pass
for epoch in range(epochs):
    dense_output = softmax_input @ dense_weights + dense_bias

    # Softmax over the feature/class dimension
    softmax_output = softmax(dense_output, axis=1)

# Save final output
softmax_output.astype(np.float64).tofile(
    "../data/SoftmaxLayer_Test_1_output.bin"
)

# %% [markdown]
# ## Softmax layer test with binary classification

# %%
import numpy as np

# ============================================================
# Classification_Test_1
# ============================================================

DATA_SEED = 20260905
WEIGHT_SEED = 20260906

SAMPLES = 1024
FEATURES = 8

BATCH_SIZE = 256
EPOCHS = 200
LEARNING_RATE = 0.01

num_batches = SAMPLES // BATCH_SIZE


# ------------------------------------------------------------
# Helpers
# ------------------------------------------------------------

def he_init(rng, fan_in, fan_out):
    return (
        rng.standard_normal((fan_in, fan_out)).astype(np.float64)
        * np.sqrt(2.0 / fan_in)
    )


def softmax(z):
    z = z - np.max(z, axis=1, keepdims=True)
    e = np.exp(z)
    return e / np.sum(e, axis=1, keepdims=True)


def relu(x):
    return np.maximum(x, 0.0)


# ------------------------------------------------------------
# Generate input
# ------------------------------------------------------------

rng = np.random.default_rng(DATA_SEED)

X = rng.uniform(
    -1.0,
    1.0,
    size=(SAMPLES, FEATURES)
).astype(np.float64)


# ------------------------------------------------------------
# Generate nonlinear classification target
# ------------------------------------------------------------

f = (
    np.sin(1.7 * X[:, 0])
    + 0.35 * X[:, 1] ** 2
    - 0.50 * np.tanh(X[:, 2] * X[:, 3])
    + 0.20 * np.cos(X[:, 4] + X[:, 5])
    - 0.10 * X[:, 6]
)

g = -f

labels = (g > f).astype(np.int64)


# ------------------------------------------------------------
# One-hot target
# ------------------------------------------------------------

Y = np.zeros((SAMPLES, 2), dtype=np.float64)

Y[np.arange(SAMPLES), labels] = 1.0


# ------------------------------------------------------------
# Model initialization
# ------------------------------------------------------------

rng_w = np.random.default_rng(WEIGHT_SEED)

W1 = he_init(rng_w, 8, 16)
b1 = np.zeros(16, dtype=np.float64)

W2 = he_init(rng_w, 16, 8)
b2 = np.zeros(8, dtype=np.float64)

W3 = he_init(rng_w, 8, 2)
b3 = np.zeros(2, dtype=np.float64)


# ------------------------------------------------------------
# Save input / expected output / initial parameters
# ------------------------------------------------------------

X.astype(np.float64).tofile(
    "../data/Classification_Test_1_input.bin"
)

Y.astype(np.float64).tofile(
    "../data/Classification_Test_1_output.bin"
)

W1.astype(np.float64).tofile(
    "../data/Classification_Test_1_dense1_weight.bin"
)

b1.astype(np.float64).tofile(
    "../data/Classification_Test_1_dense1_bias.bin"
)

W2.astype(np.float64).tofile(
    "../data/Classification_Test_1_dense2_weight.bin"
)

b2.astype(np.float64).tofile(
    "../data/Classification_Test_1_dense2_bias.bin"
)

W3.astype(np.float64).tofile(
    "../data/Classification_Test_1_dense3_weight.bin"
)

b3.astype(np.float64).tofile(
    "../data/Classification_Test_1_dense3_bias.bin"
)


# ------------------------------------------------------------
# Forward
# ------------------------------------------------------------

def forward(x):

    z1 = x @ W1 + b1
    a1 = relu(z1)

    z2 = a1 @ W2 + b2
    a2 = relu(z2)

    z3 = a2 @ W3 + b3
    p = softmax(z3)

    return z1, a1, z2, a2, z3, p


# ------------------------------------------------------------
# Categorical Cross Entropy error
# ------------------------------------------------------------

def cce_error(y, p):

    return -y * np.log(p)


# ------------------------------------------------------------
# Training
# ------------------------------------------------------------

# ------------------------------------------------------------
# Training
# ------------------------------------------------------------

for ep in range(EPOCHS):

    epoch_loss = 0.0

    for batch_idx in range(num_batches):

        start = batch_idx * BATCH_SIZE
        end = start + BATCH_SIZE

        x_batch = X[start:end, :]
        y_batch = Y[start:end, :]

        # ----------------------------------------------------
        # Forward
        # ----------------------------------------------------

        z1, a1, z2, a2, z3, y_pred = forward(x_batch)

        # ----------------------------------------------------
        # CCE error
        # ----------------------------------------------------

        error_loss = cce_error(y_batch, y_pred)

        # The framework stores one loss value per class and sample, then
        # reduces the complete [classes, batch] tensor with mean().
        loss = np.mean(error_loss)

        epoch_loss += loss

        # ----------------------------------------------------
        # Print batch loss
        # ----------------------------------------------------

        print(f"{loss:.6f}")

        # ----------------------------------------------------
        # Backward
        # ----------------------------------------------------

        # The framework differentiates the unreduced elementwise CCE
        # tensor, so its batch gradient is a sum, not a mean.
        grad_z3 = y_pred - y_batch

        grad_w3 = a2.T @ grad_z3
        grad_b3 = np.sum(grad_z3, axis=0)

        grad_a2 = grad_z3 @ W3.T
        grad_z2 = grad_a2 * (z2 > 0.0)

        grad_w2 = a1.T @ grad_z2
        grad_b2 = np.sum(grad_z2, axis=0)

        grad_a1 = grad_z2 @ W2.T
        grad_z1 = grad_a1 * (z1 > 0.0)

        grad_w1 = x_batch.T @ grad_z1
        grad_b1 = np.sum(grad_z1, axis=0)

        # ----------------------------------------------------
        # SGD update
        # ----------------------------------------------------

        W3 -= LEARNING_RATE * grad_w3
        b3 -= LEARNING_RATE * grad_b3

        W2 -= LEARNING_RATE * grad_w2
        b2 -= LEARNING_RATE * grad_b2

        W1 -= LEARNING_RATE * grad_w1
        b1 -= LEARNING_RATE * grad_b1

        # ----------------------------------------------------
        # Last batch of final epoch
        # ----------------------------------------------------

        if ep == EPOCHS - 1 and batch_idx == num_batches - 1:
            final_batch_error_loss = error_loss.copy()
            final_batch_loss = loss

    epoch_loss /= num_batches


print("==========================================")
print("Classification_Test_1")
print("==========================================")

print(f"Final epoch loss : {epoch_loss:.17g}")
print(f"Last batch loss  : {final_batch_loss:.17g}")

print("==========================================")
# Out:
# 0.371544
# 0.392767
# 0.450043
# 0.346654
# 0.329370
# 0.311005
# 0.288934
# 0.222810
# 0.229019
# 0.822563
# 0.368793
# 0.216037
# 0.322053
# 0.432805
# 0.227703
# 0.128994
# 0.079558
# 0.056559
# 0.078777
# 0.060156
# 0.056580
# 0.044219
# 0.069222
# 0.063057
# 0.055157
# 0.042273
# 0.063785
# 0.059509
# 0.047859
# 0.036000
# 0.055082
# 0.047542
# 0.043178
# 0.030079
# 0.048465
# 0.039271
# 0.041257
# 0.026620
# 0.043923
# 0.034045
# 0.039147
# 0.023721
# 0.040073
# 0.032763
# 0.036494
# 0.023088
# 0.038132
# 0.035110
# 0.041529
# 0.039014
# 0.075755
# 0.149921
# 0.159510
# 0.087649
# 0.051574
# 0.043356
# 0.034794
# 0.023809
# 0.036288
# 0.030351
# 0.026474
# 0.016905
# 0.031261
# 0.026138
# 0.028042
# 0.018267
# 0.028970
# 0.027105
# 0.030669
# 0.019855
# 0.028197
# 0.028888
# 0.024499
# 0.014019
# 0.022412
# 0.017556
# 0.022978
# 0.016860
# 0.033251
# 0.043478
# 0.048346
# 0.020282
# 0.029344
# 0.032943
# 0.035306
# 0.014809
# 0.023715
# 0.012851
# 0.015392
# 0.008277
# ...

# %% [markdown]
# # Relu

# %% [markdown]
# ## Test 1

# %%
import numpy as np
np.random.seed(9)

def relu(x):
    return np.maximum(0, x)

data_32_63 = 5 * np.random.rand(32, 63) - 0.5; # shift by -0.5 then scale by 5
output_32_63 = relu(data_32_63)  # Output: [0 0 0 1 2]
print(data_32_63[0])
print(output_32_63[0])

data_32_63.astype(data_32_63.astype(np.float64).tofile("../data/Relu_Test_1_input_sample.bin"))
output_32_63.astype(output_32_63.astype(np.float64).tofile("../data/Relu_Test_1_output_sample.bin"))
# Out:
# [-0.44812923  2.00937296  1.97886647  0.16914764  0.21055543  0.59279338
#   1.5925409   0.74050584 -0.07970174  1.2274932   0.33388173  3.89279543
#   4.25482016 -0.30625812  2.99553696  2.36379908  3.99003559  2.83449486
#   2.23918892  3.01213712  1.43238585  2.97219339  3.62435232  1.82834238
#   4.20262205  3.51869885  4.41679624  0.34818129  2.10542356  4.22758708
#   2.74770232  3.80415962  4.35423006  0.42770843  0.71557838  3.86700422
#   4.03138638  3.29138993  1.23450977  1.81767357  2.5526887   1.98140859
#   1.88987007  1.67777732  3.85204148  0.43679324  2.93837047  3.01764587
#   4.12600039 -0.30272591  2.73558357  2.69026992  1.80848831 -0.23470288
#  -0.30714538  0.34765707  3.47273943  0.31303023  0.1936935   1.26458477
#   1.92249228  2.98868193  3.50578216]
# [0.         2.00937296 1.97886647 0.16914764 0.21055543 0.59279338
#  1.5925409  0.74050584 0.         1.2274932  0.33388173 3.89279543
#  4.25482016 0.         2.99553696 2.36379908 3.99003559 2.83449486
# ...

# %% [markdown]
# ## Test_2

# %%
import numpy as np
np.random.seed(3)

def relu(x):
    return np.maximum(0, x)

data_72_36_48_51 = 5 * (np.random.rand(72, 36, 48, 51) - 0.75); # shift by -0.5 then scale by 5
output_72_36_48_51 = relu(data_72_36_48_51)  # Output: [0 0 0 1 2]
print(data_72_36_48_51[0])
print(output_72_36_48_51[0])

data_72_36_48_51.astype(data_72_36_48_51.astype(np.float64).tofile("../data/Relu_Test_2_input_sample.bin"))
output_72_36_48_51.astype(output_72_36_48_51.astype(np.float64).tofile("../data/Relu_Test_2_output_sample.bin"))
# Out:
# [[[-0.99601049 -0.20926089 -2.29547631 ... -2.36011247 -1.47688962
#    -2.72294828]
#   [-2.74310644 -1.1798247  -3.31385316 ... -2.76809712 -2.78963852
#    -0.12165188]
#   [ 0.17468352  1.11049182  0.50485709 ... -2.18090442 -1.65208622
#     0.63606019]
#   ...
#   [-3.3575399  -2.83207904  0.90113235 ... -0.19636435 -1.71480937
#    -0.70889182]
#   [-2.94115609 -0.88968176  0.46028724 ...  0.62434126  0.59645208
#    -0.04694538]
#   [-0.85116868 -3.68560301 -2.85860662 ...  0.04357109 -1.92002463
#    -1.51016559]]
#
#  [[ 1.19027728 -3.69209942 -3.32720825 ... -2.2560505  -0.12914641
#    -3.05847836]
#   [ 1.14489475 -2.37379692  0.51214448 ... -1.37644955 -0.05677373
#    -1.14904876]
#   [-2.27272303  0.48056712 -1.47264425 ...  0.30418418  0.3277082
#    -2.34246414]
#   ...
#   [ 0.04690182 -0.25721891 -3.56703516 ... -1.2599603  -2.71683753
#     1.16116767]
#   [-1.57338616 -2.939217   -3.55967973 ... -3.58922507  0.74134454
#     0.33639653]
# ...

# %% [markdown]
# ## Test_3

# %%
import numpy as np
np.random.seed(11)

def relu(x):
    return np.maximum(0, x)

# Logical tensor shapes. In the C++ test these correspond to:
# A.tf_create(tf_float64, 18, 32), B.tf_create(tf_float64, 18, 32), D.tf_create(tf_float64, 34, 18)
A_32_18 = 5 * (np.random.rand(32, 18) - 0.5)
B_32_18 = 5 * (np.random.rand(32, 18) - 0.5)
D_18_34 = 5 * (np.random.rand(18, 34) - 0.5)

# forward
C_32_18 = A_32_18 - B_32_18
E_32_18 = relu(C_32_18)
F_32_34 = np.matmul(E_32_18, D_18_34)
G_32_18 = np.power(E_32_18, 3)

# backprop for L = sum(F) + sum(G)
dF_32_34 = np.ones_like(F_32_34)
dG_32_18 = np.ones_like(G_32_18)

dE_from_F_32_18 = np.matmul(dF_32_34, D_18_34.T)
dD_18_34 = np.matmul(E_32_18.T, dF_32_34)

dE_from_G_32_18 = 3 * np.power(E_32_18, 2) * dG_32_18
dE_32_18 = dE_from_F_32_18 + dE_from_G_32_18

dC_32_18 = dE_32_18 * (C_32_18 > 0)
dA_32_18 = dC_32_18
dB_32_18 = -dC_32_18

A_32_18.astype(np.float64).tofile("../data/Relu_Test_3_A_input.bin")
B_32_18.astype(np.float64).tofile("../data/Relu_Test_3_B_input.bin")
D_18_34.astype(np.float64).tofile("../data/Relu_Test_3_D_input.bin")
C_32_18.astype(np.float64).tofile("../data/Relu_Test_3_C_output.bin")
E_32_18.astype(np.float64).tofile("../data/Relu_Test_3_E_output.bin")
F_32_34.astype(np.float64).tofile("../data/Relu_Test_3_F_output.bin")
G_32_18.astype(np.float64).tofile("../data/Relu_Test_3_G_output.bin")
dA_32_18.astype(np.float64).tofile("../data/Relu_Test_3_A_grad.bin")
dB_32_18.astype(np.float64).tofile("../data/Relu_Test_3_B_grad.bin")
dD_18_34.astype(np.float64).tofile("../data/Relu_Test_3_D_grad.bin")
dC_32_18.astype(np.float64).tofile("../data/Relu_Test_3_C_grad.bin")
dE_32_18.astype(np.float64).tofile("../data/Relu_Test_3_E_grad.bin")

print("A", A_32_18.shape, "B", B_32_18.shape, "D", D_18_34.shape)
print("C", C_32_18.shape, "E", E_32_18.shape, "F", F_32_34.shape, "G", G_32_18.shape)
print("dA", dA_32_18.shape, "dB", dB_32_18.shape, "dD", dD_18_34.shape)
# Out:
# A (32, 18) B (32, 18) D (18, 34)
# C (32, 18) E (32, 18) F (32, 34) G (32, 18)
# dA (32, 18) dB (32, 18) dD (18, 34)

# %% [markdown]
# ## Test 4: max ones

# %%
import numpy as np

np.random.seed(53)

A_89_78 = np.random.rand(89, 78)
output_89_78 = np.greater(A_89_78, 0).astype(np.float32)


A_89_78.astype(np.float64).tofile("../data/GreaterThanZero_Test_1_input_sample.bin")
output_89_78.astype(np.float64).tofile("../data/GraterThanZeor_Test_1_output_sample.bin")

# %% [markdown]
# ## TEST_5: Relu incombination with dense layer

# %% [markdown]
# ### NumPy reference generator

# %%
import numpy as np
from pathlib import Path


def relu(x):
    return np.maximum(x, 0.0)


def write_bin(output_dir, filename, values):
    path = output_dir / filename
    np.asarray(values, dtype=np.float64).tofile(path)
    return path


# Dense + ReLU validator
# C++ graph shape:
#   input       : tf_create(tf_float64, 43, 512)
#   dense weight: tf_create(tf_float64, 32, 43)
#   dense bias  : tf_create(tf_float64, 32, 1)
#   dense_layer = dense(32)(input)
#   relu_layer  = relu()(dense_layer)
# NumPy keeps samples on axis 0. C-order flattening matches the C++ tensor
# memory order used by the dense-layer tests: feature/unit + sample * rows.
rng = np.random.default_rng(105)
output_dir = Path("../data")

sample_size = 512
input_features = 43
dense_units = 32
learning_rate = 0.01

x_input = rng.normal(loc=0.0, scale=1.0, size=(sample_size, input_features))
target_output = rng.normal(loc=0.0, scale=1.0, size=(sample_size, dense_units))
weights = rng.normal(loc=0.0, scale=0.15, size=(input_features, dense_units))
bias = rng.normal(loc=0.0, scale=0.25, size=(dense_units,))

# Forward pass: dense(32) -> relu
dense_output = x_input @ weights + bias
relu_output = relu(dense_output)

# Squared-error loss, same per-output-unit reduction style as
# DenseLayer_Loss_Integration.
error = relu_output - target_output
loss = np.mean(error * error, axis=0)

# Backward pass through ReLU into dense.
grad_relu_output = (2.0 / sample_size) * error
grad_dense_output = grad_relu_output * (dense_output > 0.0)
grad_weight = x_input.T @ grad_dense_output
grad_bias = np.sum(grad_dense_output, axis=0)
grad_input = grad_dense_output @ weights.T

updated_weight = weights - learning_rate * grad_weight
updated_bias = bias - learning_rate * grad_bias

files = {
    "input": write_bin(output_dir, "ReluDense_Test_5_input_data.bin", x_input),
    "target_output": write_bin(output_dir, "ReluDense_Test_5_target_output_data.bin", target_output),
    "weight": write_bin(output_dir, "ReluDense_Test_5_weight_data.bin", weights),
    "bias": write_bin(output_dir, "ReluDense_Test_5_bias_data.bin", bias),
    "dense_output": write_bin(output_dir, "ReluDense_Test_5_dense_output_data.bin", dense_output),
    "relu_output": write_bin(output_dir, "ReluDense_Test_5_relu_output_data.bin", relu_output),
    "loss": write_bin(output_dir, "ReluDense_Test_5_loss_data.bin", loss),
    "grad_relu_output": write_bin(output_dir, "ReluDense_Test_5_grad_relu_output_data.bin", grad_relu_output),
    "grad_dense_output": write_bin(output_dir, "ReluDense_Test_5_grad_dense_output_data.bin", grad_dense_output),
    "grad_weight": write_bin(output_dir, "ReluDense_Test_5_grad_weight_data.bin", grad_weight),
    "grad_bias": write_bin(output_dir, "ReluDense_Test_5_grad_bias_data.bin", grad_bias),
    "grad_input": write_bin(output_dir, "ReluDense_Test_5_grad_input_data.bin", grad_input),
    "updated_weight": write_bin(output_dir, "ReluDense_Test_5_updated_weight_data.bin", updated_weight),
    "updated_bias": write_bin(output_dir, "ReluDense_Test_5_updated_bias_data.bin", updated_bias),
}

print("Dense + ReLU TEST_5 reference data generated")
print(f"input: {x_input.shape}, weight: {weights.shape}, bias: {bias.shape}")
print(f"dense_output: {dense_output.shape}, relu_output: {relu_output.shape}")
print(f"loss: {loss.shape}, grad_weight: {grad_weight.shape}, grad_bias: {grad_bias.shape}")
for name, path in files.items():
    print(f"{name}: {path}")
# Out:
# Dense + ReLU TEST_5 reference data generated
# input: (512, 43), weight: (43, 32), bias: (32,)
# dense_output: (512, 32), relu_output: (512, 32)
# loss: (32,), grad_weight: (43, 32), grad_bias: (32,)
# input: ../data/ReluDense_Test_5_input_data.bin
# target_output: ../data/ReluDense_Test_5_target_output_data.bin
# weight: ../data/ReluDense_Test_5_weight_data.bin
# bias: ../data/ReluDense_Test_5_bias_data.bin
# dense_output: ../data/ReluDense_Test_5_dense_output_data.bin
# relu_output: ../data/ReluDense_Test_5_relu_output_data.bin
# loss: ../data/ReluDense_Test_5_loss_data.bin
# grad_relu_output: ../data/ReluDense_Test_5_grad_relu_output_data.bin
# grad_dense_output: ../data/ReluDense_Test_5_grad_dense_output_data.bin
# grad_weight: ../data/ReluDense_Test_5_grad_weight_data.bin
# grad_bias: ../data/ReluDense_Test_5_grad_bias_data.bin
# grad_input: ../data/ReluDense_Test_5_grad_input_data.bin
# updated_weight: ../data/ReluDense_Test_5_updated_weight_data.bin
# ...

# %% [markdown]
# # Transpose

# %% [markdown]
# #### 32_16

# %%
A_transpose_input_32_16 = np.random.rand(32,16)

# %%
print(A_transpose_input_32_16.tolist())

# %%
A_transpose_output_32_16 = A_transpose_input_32_16.T

print(A_transpose_output_32_16.tolist())

# %% [markdown]
# ####47_19

# %%
A_transpose_input = np.random.rand(47,19)
print(A_transpose_input.tolist())

# %%
A_transpose_output = A_transpose_input.T
print(A_transpose_output.tolist())

# %% [markdown]
# ###multi-dimentional 3_2_2

# %%
A_transpose_input_3_4_2 = np.random.rand(3,4,2)
print(A_transpose_input_3_4_2)

# %%
print(A_transpose_input_3_4_2.tolist())

# %%
A_transpose_input_3_4_2.shape[0], A_transpose_input_3_4_2.shape[1], A_transpose_input_3_4_2.shape[2],

# %%
print(','.join(f'{x:.{8}f}' for x in A_transpose_input_3_4_2.flatten()))

# %%
A_transpose_output_3_2_4 = A_transpose_input_3_4_2.T
print(A_transpose_output_3_2_4)

# %%
A_transpose_output_3_2_4.shape

# %% [markdown]
# # Reduce sum

# %% [markdown]
# ## Test 1

# %%
import numpy as np
np.random.seed(81)
A_73_33  = np.random.rand(73,33)
C_33  = np.sum(A_73_33, axis= 0)

A_73_33.astype(A_73_33.astype(np.float64).tofile("../data/MatrixReductionSum_Test_1_input.bin"))
C_33.astype(C_33.astype(np.float64).tofile("../data/MatrixReductionSum_Test_1_output.bin"))
# Out:
# array([38.08829826, 35.4271766 , 34.98749801, 34.12824877, 33.97511134,
#        37.70211221, 35.82118541, 39.87260129, 33.58801706, 33.21252317,
#        35.63960306, 32.68979266, 36.03343976, 34.39692129, 32.56168847,
#        40.13936238, 39.89908915, 39.02528295, 39.29248191, 39.86631909,
#        34.48132858, 32.68478005, 33.47650533, 36.54584714, 33.84782826,
#        38.36761144, 41.62095117, 32.96599149, 32.76653515, 38.19468439,
#        37.86698291, 35.30812105, 30.93305655])

# %% [markdown]
# ## Test 2

# %%
import numpy as np
np.random.seed(101)
A_13_78_65 = np.random.rand(13,78,65)
C_78 = np.sum(A_13_78_65, axis=(0,2))

A_13_78_65.astype(A_13_78_65.astype(np.float64).tofile("../data/MatrixReductionSum_Test_2_input.bin"))
C_78.astype(C_78.astype(np.float64).tofile("../data/MatrixReductionSum_Test_2_output.bin"))
# Out:
# array([420.71333424, 420.21225341, 436.35024191, 427.20085964,
#        413.90072715, 425.61572941, 431.49220455, 424.4681393 ,
#        422.55404522, 424.74368959, 424.25225067, 419.95232193,
#        417.4445956 , 436.52359991, 425.20190767, 416.95438401,
#        433.25909976, 427.53924453, 436.2065563 , 419.53629873,
#        424.09195486, 413.55135331, 423.56471643, 420.1403654 ,
#        428.61661721, 426.53256055, 421.14416035, 409.41620448,
#        407.0653384 , 431.25177298, 410.81906788, 416.56164734,
#        425.8176966 , 415.76522732, 423.92934092, 416.8729191 ,
#        413.46141917, 432.29182377, 430.36773871, 413.62095551,
#        430.7271051 , 422.58198475, 419.33061977, 428.47780276,
#        412.91804069, 425.49405545, 431.95798972, 416.98993846,
#        442.89833391, 424.56103788, 440.39159953, 415.51858676,
#        422.57413309, 419.7615764 , 434.86822122, 415.00181449,
#        427.02009507, 423.07182645, 430.62547053, 435.7908485 ,
# ...

# %% [markdown]
# # GEMM kernel aka dense layer

# %% [markdown]
# ## Test 1, DenseLayer_Loss_Integration

# %%
np.random.seed(32)


batch_size = 128

x_input = np.random.rand(batch_size, 43)
y_output = np.random.rand(batch_size, 32)
weights = np.random.rand(43,32)
bias = np.random.rand(32)

print('Inputs')
print(','.join(f'{x:.{8}f}' for x in x_input.flatten()))
print(','.join(f'{x:.{8}f}' for x in y_output.flatten()))
print(','.join(f'{x:.{8}f}' for x in weights.flatten()))
print(','.join(f'{x:.{8}f}' for x in bias.flatten()))

# --------------------
# forward
# --------------------
y_hat = np.matmul(x_input, weights) + bias

print('Output')
print(','.join(f'{x:.{8}f}' for x in y_hat.flatten()))

# --------------------
# (Loss)
# --------------------
error = y_hat - y_output

loss = loss = np.sum(error ** 2, axis=0) / batch_size   # scalar
print("Loss:")
print(','.join(f'{x:.8f}' for x in loss.flatten()))

# --------------------
# gradient
# --------------------
grad_loss = (2.0 / batch_size) * error      # dL/dY_hat
grad_weight = np.matmul(x_input.T, grad_loss)
grad_bias = np.sum(grad_loss, axis=0)


print("Gradients:")
print(','.join(f'{x:.8f}' for x in grad_loss.flatten()))
print(','.join(f'{x:.8f}' for x in grad_weight.flatten()))
print(','.join(f'{x:.8f}' for x in grad_bias.flatten()))

learning_rate = 0.01
updated_weight = weights - learning_rate * grad_weight
updated_bias = bias - learning_rate * grad_bias

print("Updated Weights bias")
print(','.join(f'{x:.8f}' for x in updated_weight.flatten()))
print(','.join(f'{x:.8f}' for x in updated_bias.flatten()))
# Out:
# Inputs
# ...

# %% [markdown]
# ## Test 2, DenseLayer_Loss_Integration_parameter_update_multiple_epochs

# %%
from dataclasses import dataclass
from typing import Dict
import numpy as np


@dataclass
class DenseTest4SimulateEpoch:
    x: np.ndarray  # (sample_size, in_features)
    w: np.ndarray  # (in_features, dense_units)
    b: np.ndarray  # (dense_units,)
    y: np.ndarray  # (sample_size, dense_units)


def load_dense_test_4(
    sample_size: int,
    no_of_input_features: int,
    no_of_dense_units: int,
    seed: int = 77,
) -> DenseTest4SimulateEpoch:
    rng = np.random.default_rng(seed)
    x = rng.random((sample_size, no_of_input_features))
    w = rng.random((no_of_input_features, no_of_dense_units))
    b = rng.random((no_of_dense_units,))
    y = rng.random((sample_size, no_of_dense_units))
    return DenseTest4SimulateEpoch(x=x, w=w, b=b, y=y)


def simulate_training(
    data: DenseTest4SimulateEpoch,
    epochs: int,
    batch_size: int,
    learning_rate: float,
) -> Dict[str, np.ndarray]:
    x, w, b, y = data.x, data.w, data.b, data.y

    if epochs <= 0:
        raise ValueError("epochs must be > 0")
    if batch_size <= 0 or batch_size > x.shape[0]:
        raise ValueError(f"batch_size must be in [1, {x.shape[0]}]")
    if x.shape[0] != y.shape[0]:
        raise ValueError("x and y must have same sample size")

    sample_size = x.shape[0]
    num_batches = sample_size // batch_size  # drop remainder
    if num_batches == 0:
        raise ValueError("batch_size is too large; no full batch available")

    all_batch_index = []
    all_input_batch = []
    all_output_batch = []
    all_loss_batch = []
    all_grad_loss = []
    all_grad_weight = []
    all_grad_bias = []
    all_updated_weight = []
    all_updated_bias = []
    all_target_output = []

    curr_w = w.copy()
    curr_b = b.copy()

    # One batch per epoch-step, rolling over full batches in order.
    for ep in range(epochs):
        epoch_loss = 0.0
        for batch_idx in range(num_batches):
            start = batch_idx * batch_size
            end = start + batch_size

            x_batch = x[start:end, :]  # (batch_size, in_features)
            y_batch = y[start:end, :]  # (batch_size, dense_units)

            output = x_batch @ curr_w + curr_b
            diff = output - y_batch
            loss = np.mean(diff * diff, axis=0)
            epoch_loss += loss

            grad_loss = (2.0 / batch_size) * diff
            grad_weight = x_batch.T @ grad_loss
            grad_bias = np.sum(grad_loss, axis=0)

            updated_w = curr_w - learning_rate * grad_weight
            updated_b = curr_b - learning_rate * grad_bias
            print(loss.shape)

            all_batch_index.append(batch_idx)
            all_input_batch.append(x_batch.copy())
            all_output_batch.append(output.copy())
            all_loss_batch.append(loss.copy())
            all_grad_loss.append(grad_loss.copy())
            all_grad_weight.append(grad_weight.copy())
            all_grad_bias.append(grad_bias.copy())
            all_updated_weight.append(updated_w.copy())
            all_updated_bias.append(updated_b.copy())
            all_target_output.append(y_batch.copy())

            # step-wise SGD update continuity
            curr_w = updated_w
            curr_b = updated_b

        epoch_loss /= num_batches

    return {
        "batch_index": np.array(all_batch_index, dtype=np.int64),
        "input": np.stack(all_input_batch, axis=0),
        "output": np.stack(all_output_batch, axis=0),
        "target_output": np.stack(all_target_output, axis=0),
        "loss": np.stack(all_loss_batch, axis=0),
        "grad_loss": np.stack(all_grad_loss, axis=0),
        "grad_weight": np.stack(all_grad_weight, axis=0),
        "grad_bias": np.stack(all_grad_bias, axis=0),
        "updated_weight": np.stack(all_updated_weight, axis=0),
        "updated_bias": np.stack(all_updated_bias, axis=0),
    }

# %%
data = load_dense_test_4(128, 17, 19)
all_data = simulate_training(data, epochs=10, batch_size=32, learning_rate=0.01)



data.x.astype(data.x.astype(np.float64).tofile("../data/DenseLayer_Test_2_input_data.bin"))
data.w.astype(data.w.astype(np.float64).tofile("../data/DenseLayer_Test_2_weights_data.bin"))
data.b.astype(data.b.astype(np.float64).tofile("../data/DenseLayer_Test_2_bias_data.bin"))
data.y.astype(data.y.astype(np.float64).tofile("../data/DenseLayer_Test_2_output_data.bin"))


all_data["input"].astype(all_data["input"].astype(np.float64).tofile("../data/DenseLayer_Test_2_input_batch_data.bin"))
all_data["output"].astype(all_data["output"].astype(np.float64).tofile("../data/DenseLayer_Test_2_output_batch_data.bin"))
all_data["target_output"].astype(all_data["target_output"].astype(np.float64).tofile("../data/DenseLayer_Test_2_target_output_batch_data.bin"))
all_data["loss"].astype(all_data["loss"].astype(np.float64).tofile("../data/DenseLayer_Test_2_loss_batch_data.bin"))
all_data["grad_loss"].astype(all_data["grad_loss"].astype(np.float64).tofile("../data/DenseLayer_Test_2_grad_loss_batch_data.bin"))
all_data["grad_weight"].astype(all_data["grad_weight"].astype(np.float64).tofile("../data/DenseLayer_Test_2_grad_weight_batch_data.bin"))
all_data["grad_bias"].astype(all_data["grad_bias"].astype(np.float64).tofile("../data/DenseLayer_Test_2_grad_bias_batch_data.bin"))
all_data["updated_weight"].astype(all_data["updated_weight"].astype(np.float64).tofile("../data/DenseLayer_Test_2_updated_weight_batch_data.bin"))
all_data["updated_bias"].astype(all_data["updated_bias"].astype(np.float64).tofile("../data/DenseLayer_Test_2_updated_bias_batch_data.bin"))
# Out:
# array([[ 0.45963976,  0.34805605,  0.47336097,  0.54985826,  0.26354721,
#          0.44290642,  0.3007656 ,  0.85919608,  0.24037122,  0.48040233,
#          0.57365689,  0.163738  ,  0.59708554,  0.20559097,  0.08451546,
#          0.1744901 ,  0.14809537,  0.65384013,  0.14483026],
#        [ 0.39901446,  0.27066007,  0.39804312,  0.4580888 ,  0.19326552,
#          0.38149115,  0.21185475,  0.78730074,  0.18527446,  0.4127007 ,
#          0.4840861 ,  0.08159714,  0.50226504,  0.13937209,  0.03035979,
#          0.10504353,  0.04289809,  0.58718158,  0.08353726],
#        [ 0.34764829,  0.20522253,  0.33428554,  0.38097488,  0.13337627,
#          0.32582414,  0.13752937,  0.72622729,  0.1362457 ,  0.35205075,
#          0.40251819,  0.00665751,  0.42261815,  0.08088389, -0.01659866,
#          0.04764829, -0.04705302,  0.52701818,  0.03413419],
#        [ 0.2991738 ,  0.14936444,  0.27637973,  0.31405249,  0.08153595,
# ...

# %%
all_data["target_output"][0].shape
# Out:
# (40, 19)

# %% [markdown]
# ## Test 3, double dense layer convergance test

# %%
np.random.seed(42)

# -----------------------
# Config
# -----------------------
N = 512
D_in, D_hidden, D_out = 27, 31, 7
batch_size = 32
epochs = 100
lr = 0.01
noise_level = 0.01

# -----------------------
# Data (2-layer ground truth)
# -----------------------
X = np.random.randn(N, D_in)

W1_true = np.random.randn(D_in, D_hidden)
b1_true = np.random.randn(D_hidden)

W2_true = np.random.randn(D_hidden, D_out)
b2_true = np.random.randn(D_out)

Z_true = X @ W1_true + b1_true
Y = Z_true @ W2_true + b2_true

# Add noise
Y += noise_level * np.random.randn(*Y.shape)

# -----------------------
# Model init
# -----------------------
W1 = 0.01 * np.random.randn(D_in, D_hidden)
b1 = np.zeros(D_hidden)


W2 = 0.01 * np.random.randn(D_hidden, D_out)
b2 = np.zeros(D_out)


W1_pretrainning = W1.copy()
b1_pretraining = b1.copy()
W2_pretrainning = W2.copy()
b2_pretraining = b2.copy()

all_batch_index = []
all_input = []
all_output = []
all_loss = []
all_grad_loss = []
all_grad_weight_1 = []
all_grad_bias_1 = []
all_updated_weights_1 = []
training_weights_1_batch = []
training_weights_2_batch = []
all_updated_bias_1 = []
all_grad_weights_2 = []
all_grad_bias_2 = []
all_updated_weights_2 = []
all_updated_bias_2 = []
all_target_output = []


# -----------------------
# Training
# -----------------------
num_batches = N // batch_size

for epoch in range(epochs):
    epoch_loss = 0.0

    for i in range(num_batches):
        training_weights_1_batch.append(W1.copy())
        training_weights_2_batch.append(W2.copy())
        
        s = i * batch_size
        e = s + batch_size

        Xb = X[s:e]
        Yb = Y[s:e]

        # Forward
        Z1 = Xb @ W1 + b1
        Yp = Z1 @ W2 + b2

        # Loss
        sample_loss = np.mean((Yp - Yb) ** 2, axis=1)
        loss = np.mean(sample_loss)
        epoch_loss += loss

        # Backward
        dY =  (2.0 / batch_size) * (Yp - Yb)

        dW2 = Z1.T @ dY
        db2 = np.sum(dY, axis=0)

        dZ1 = dY @ W2.T

        dW1 = Xb.T @ dZ1
        db1 = np.sum(dZ1, axis=0)

        # Update
        W1 -= lr * dW1
        b1 -= lr * db1
        W2 -= lr * dW2
        b2 -= lr * db2

        all_input.append(Xb.copy())
        all_updated_bias_1.append(b1.copy())
        all_updated_bias_2.append(b2.copy())
        all_grad_weights_2.append(dW2.copy())
        all_updated_weights_1.append(W1.copy())
        all_updated_weights_2.append(W2.copy())
        all_grad_loss.append(dY.copy())


    epoch_loss /= num_batches
    all_loss.append(epoch_loss.copy())

    if epoch % 5 == 0:
        print(f"Epoch {epoch:3d} | Loss: {epoch_loss:.6f}")

# -----------------------
# Verification
# -----------------------
Y_pred = (X @ W1 + b1) @ W2 + b2
print("\nFinal MSE:", np.mean((Y_pred - Y) ** 2))

# Effective weights check
W_eff = W1 @ W2
b_eff = b1 @ W2 + b2

W_true_eff = W1_true @ W2_true
b_true_eff = b1_true @ W2_true + b2_true

print("W error:", np.linalg.norm(W_eff - W_true_eff))
print("b error:", np.linalg.norm(b_eff - b_true_eff))
# Out:
# Epoch   0 | Loss: 816.470230
# Epoch   5 | Loss: 166.549267
# Epoch  10 | Loss: 11.895480
# Epoch  15 | Loss: 0.366422
# Epoch  20 | Loss: 0.005140
# Epoch  25 | Loss: 0.000263
# Epoch  30 | Loss: 0.000115
# Epoch  35 | Loss: 0.000109
# Epoch  40 | Loss: 0.000108
# Epoch  45 | Loss: 0.000108
# Epoch  50 | Loss: 0.000108
# Epoch  55 | Loss: 0.000108
# Epoch  60 | Loss: 0.000108
# Epoch  65 | Loss: 0.000108
# Epoch  70 | Loss: 0.000108
# Epoch  75 | Loss: 0.000108
# Epoch  80 | Loss: 0.000108
# Epoch  85 | Loss: 0.000108
# Epoch  90 | Loss: 0.000108
# Epoch  95 | Loss: 0.000108
#
# Final MSE: 0.0001022861394873755
# W error: 0.008071461314493968
# b error: 0.0014420558502805992

# %%
X.astype(X.astype(np.float64).tofile("../data/DenseLayer_Test_3_input_sample.bin"))
W1_pretrainning.astype(W1_pretrainning.astype(np.float64).tofile("../data/DenseLayer_Test_3_weights_1.bin"))
b1_pretraining.astype(b1_pretraining.astype(np.float64).tofile("../data/DenseLayer_Test_3_bias_1.bin"))
W2_pretrainning.astype(W2_pretrainning.astype(np.float64).tofile("../data/DenseLayer_Test_3_weights_2.bin"))
b2_pretraining.astype(b2_pretraining.astype(np.float64).tofile("../data/DenseLayer_Test_3_bias_2.bin"))
Y.astype(Y.astype(np.float64).tofile("../data/DenseLayer_Test_3_target_output.bin"))

all_batch_input_nparray = np.array(all_input, dtype=np.float64)
all_updated_bias_1_nparray = np.array(all_updated_bias_1, dtype=np.float64)
all_updated_bias_2_nparray = np.array(all_updated_bias_2, dtype=np.float64)
all_updated_weights_1_nparray = np.array(all_updated_weights_1, dtype=np.float64)
all_updated_weights_2_nparray = np.array(all_updated_weights_2, dtype=np.float64)
all_grad_weights_2_nparray = np.array(all_grad_weights_2, dtype=np.float64)
training_weights_1_batch_nparray = np.array(training_weights_1_batch, dtype=np.float64)
training_weights_2_batch_nparray = np.array(training_weights_2_batch, dtype=np.float64)
all_loss_grad_nparray = np.array(all_grad_loss, dtype=np.float64)
all_loss_nparray = np.array(all_loss, dtype=np.float64)


all_batch_input_nparray.tofile("../data/DenseLayer_Test_3_batch_input_history.bin")
all_updated_bias_1_nparray.tofile("../data/DenseLayer_Test_3_b1_history.bin")
all_updated_bias_2_nparray.tofile("../data/DenseLayer_Test_3_b2_history.bin")
all_updated_weights_1_nparray.tofile("../data/DenseLayer_Test_3_w1_history.bin")
all_updated_weights_2_nparray.tofile("../data/DenseLayer_Test_3_w2_history.bin")
all_loss_grad_nparray.tofile("../data/DenseLayer_Test_3_loss_grad_batch_end_history.bin")
training_weights_1_batch_nparray.tofile("../data/DenseLayer_Test_3_w1_batch_begin_history.bin")
all_grad_weights_2_nparray.tofile("../data/DenseLayer_Test_3_w2_grad_batch_end_history.bin")
training_weights_2_batch_nparray.tofile("../data/DenseLayer_Test_3_w2_batch_begin_history.bin")
all_loss_nparray.tofile("../data/DenseLayer_Test_3_epoch_loss.bin")

# %%
print(len(all_grad_loss))
all_grad_loss[0].shape
# Out:
# 200
# (256, 7)

# %%
all_grad_loss[0][0]
# Out:
# array([-0.19713389,  0.10306148, -0.05894989,  0.02465882,  0.11653103,
#         0.46316999, -0.17968354])

# %%
all_grad_loss[0][255]
# Out:
# array([ 0.1042319 ,  0.01184133, -0.17582231,  0.01466936, -0.19071187,
#        -0.19409609,  0.15528892])

# %% [markdown]
# # Non-linear function integration tests

# %% [markdown]
# ## quadratic formula y = x^2

# %%
# Quadratic function y = x^2
import numpy as np
from pathlib import Path


def relu(x):
    return np.maximum(x, 0.0)


def relu_grad(x):
    return (x > 0.0).astype(np.float64)


def write_bin(output_dir, filename, values):
    path = output_dir / filename
    np.asarray(values, dtype=np.float64).tofile(path)
    return path


rng = np.random.default_rng(2048)
output_dir = Path("../data")

sample_size = 1024
input_features = 1
hidden_units = 8
output_features = 1
batch_size = 32
epochs = 1000
learning_rate = 0.01

# Data set: 1024 scalar inputs and their quadratic targets.
x_input = np.linspace(-1.0, 1.0, sample_size, dtype=np.float64).reshape(sample_size, input_features)
target_output = x_input * x_input

# Model architecture: dense(8) -> relu() -> dense(1).
weights_1 = rng.normal(loc=0.0, scale=0.25, size=(input_features, hidden_units))
bias_1 = np.zeros(hidden_units, dtype=np.float64)
weights_2 = rng.normal(loc=0.0, scale=0.25, size=(hidden_units, output_features))
bias_2 = np.zeros(output_features, dtype=np.float64)

initial_weights_1 = weights_1.copy()
initial_bias_1 = bias_1.copy()
initial_weights_2 = weights_2.copy()
initial_bias_2 = bias_2.copy()

num_batches = sample_size // batch_size
input_batch_history = []
target_output_batch_history = []
predicted_output_batch_history = []
loss_batch_history = []

for epoch in range(epochs):
    for batch_index in range(num_batches):
        start = batch_index * batch_size
        end = start + batch_size

        x_batch = x_input[start:end]
        target_batch = target_output[start:end]

        dense_1_output = x_batch @ weights_1 + bias_1
        relu_output = relu(dense_1_output)
        predicted_output = relu_output @ weights_2 + bias_2

        error = predicted_output - target_batch
        loss = np.mean(error * error)

        grad_predicted_output = (2.0 / batch_size) * error
        grad_weights_2 = relu_output.T @ grad_predicted_output
        grad_bias_2 = np.sum(grad_predicted_output, axis=0)
        grad_relu_output = grad_predicted_output @ weights_2.T
        grad_dense_1_output = grad_relu_output * relu_grad(dense_1_output)
        grad_weights_1 = x_batch.T @ grad_dense_1_output
        grad_bias_1 = np.sum(grad_dense_1_output, axis=0)

        weights_1 -= learning_rate * grad_weights_1
        bias_1 -= learning_rate * grad_bias_1
        weights_2 -= learning_rate * grad_weights_2
        bias_2 -= learning_rate * grad_bias_2

        input_batch_history.append(x_batch.copy())
        target_output_batch_history.append(target_batch.copy())
        predicted_output_batch_history.append(predicted_output.copy())
        loss_batch_history.append(loss)

final_predicted_output = relu(x_input @ weights_1 + bias_1) @ weights_2 + bias_2
final_loss = np.mean((final_predicted_output - target_output) ** 2)

input_batch_history = np.array(input_batch_history, dtype=np.float64)
target_output_batch_history = np.array(target_output_batch_history, dtype=np.float64)
predicted_output_batch_history = np.array(predicted_output_batch_history, dtype=np.float64)
loss_batch_history = np.array(loss_batch_history, dtype=np.float64)

files = {
    "input": write_bin(output_dir, "Quadratic_ReluDense_Test_1_input_data.bin", x_input),
    "target_output": write_bin(output_dir, "Quadratic_ReluDense_Test_1_target_output_data.bin", target_output),
    "initial_weights_1": write_bin(output_dir, "Quadratic_ReluDense_Test_1_initial_weights_1.bin", initial_weights_1),
    "initial_bias_1": write_bin(output_dir, "Quadratic_ReluDense_Test_1_initial_bias_1.bin", initial_bias_1),
    "initial_weights_2": write_bin(output_dir, "Quadratic_ReluDense_Test_1_initial_weights_2.bin", initial_weights_2),
    "initial_bias_2": write_bin(output_dir, "Quadratic_ReluDense_Test_1_initial_bias_2.bin", initial_bias_2),
    "final_weights_1": write_bin(output_dir, "Quadratic_ReluDense_Test_1_final_weights_1.bin", weights_1),
    "final_bias_1": write_bin(output_dir, "Quadratic_ReluDense_Test_1_final_bias_1.bin", bias_1),
    "final_weights_2": write_bin(output_dir, "Quadratic_ReluDense_Test_1_final_weights_2.bin", weights_2),
    "final_bias_2": write_bin(output_dir, "Quadratic_ReluDense_Test_1_final_bias_2.bin", bias_2),
    "input_batch_history": write_bin(output_dir, "Quadratic_ReluDense_Test_1_input_batch_history.bin", input_batch_history),
    "target_output_batch_history": write_bin(output_dir, "Quadratic_ReluDense_Test_1_target_output_batch_history.bin", target_output_batch_history),
    "predicted_output_batch_history": write_bin(output_dir, "Quadratic_ReluDense_Test_1_predicted_output_batch_history.bin", predicted_output_batch_history),
    "loss_batch_history": write_bin(output_dir, "Quadratic_ReluDense_Test_1_loss_batch_history.bin", loss_batch_history),
    "final_predicted_output": write_bin(output_dir, "Quadratic_ReluDense_Test_1_final_predicted_output.bin", final_predicted_output),
}

print("Quadratic dense(8) -> relu -> dense training reference data generated")
print(f"input: {x_input.shape}, target_output: {target_output.shape}")
print(f"batch histories: input {input_batch_history.shape}, predicted_output {predicted_output_batch_history.shape}")
print(f"loss history: {loss_batch_history.shape}, final_loss: {final_loss:.10f}")
print(f"mean squared error: {final_loss:.10f}")
for name, path in files.items():
    print(f"{name}: {path}")
# Out:
# Quadratic dense(8) -> relu -> dense training reference data generated
# input: (1024, 1), target_output: (1024, 1)
# batch histories: input (32000, 32, 1), predicted_output (32000, 32, 1)
# loss history: (32000,), final_loss: 0.0000956505
# mean squared error: 0.0000956505
# input: ../data/Quadratic_ReluDense_Test_1_input_data.bin
# target_output: ../data/Quadratic_ReluDense_Test_1_target_output_data.bin
# initial_weights_1: ../data/Quadratic_ReluDense_Test_1_initial_weights_1.bin
# initial_bias_1: ../data/Quadratic_ReluDense_Test_1_initial_bias_1.bin
# initial_weights_2: ../data/Quadratic_ReluDense_Test_1_initial_weights_2.bin
# initial_bias_2: ../data/Quadratic_ReluDense_Test_1_initial_bias_2.bin
# final_weights_1: ../data/Quadratic_ReluDense_Test_1_final_weights_1.bin
# final_bias_1: ../data/Quadratic_ReluDense_Test_1_final_bias_1.bin
# final_weights_2: ../data/Quadratic_ReluDense_Test_1_final_weights_2.bin
# final_bias_2: ../data/Quadratic_ReluDense_Test_1_final_bias_2.bin
# ...

# %% [markdown]
# ## Cubic formula y = x^3

# %%
# Cubic function y = x^3
import numpy as np
from pathlib import Path


def relu(x):
    return np.maximum(x, 0.0)


def relu_grad(x):
    return (x > 0.0).astype(np.float64)


def write_bin(output_dir, filename, values):
    path = output_dir / filename
    np.asarray(values, dtype=np.float64).tofile(path)
    return path


rng = np.random.default_rng(4096)
output_dir = Path("../data")

sample_size = 1024
input_features = 1
hidden_units = 16
output_features = 1
batch_size = 256
epochs = 1000
learning_rate = 0.01

# Data set: 1024 scalar inputs and their cubic targets.
x_input = np.linspace(-1.0, 1.0, sample_size, dtype=np.float64).reshape(sample_size, input_features)
target_output = x_input ** 3

# Model architecture: dense(16) -> relu() -> dense(1).
weights_1 = rng.normal(loc=0.0, scale=0.25, size=(input_features, hidden_units))
bias_1 = np.zeros(hidden_units, dtype=np.float64)
weights_2 = rng.normal(loc=0.0, scale=0.25, size=(hidden_units, output_features))
bias_2 = np.zeros(output_features, dtype=np.float64)

initial_weights_1 = weights_1.copy()
initial_bias_1 = bias_1.copy()
initial_weights_2 = weights_2.copy()
initial_bias_2 = bias_2.copy()

num_batches = sample_size // batch_size
input_batch_history = []
target_output_batch_history = []
predicted_output_batch_history = []
loss_batch_history = []

for epoch in range(epochs):
    for batch_index in range(num_batches):
        start = batch_index * batch_size
        end = start + batch_size

        x_batch = x_input[start:end]
        target_batch = target_output[start:end]

        dense_1_output = x_batch @ weights_1 + bias_1
        relu_output = relu(dense_1_output)
        predicted_output = relu_output @ weights_2 + bias_2

        error = predicted_output - target_batch
        loss = np.mean(error * error)

        grad_predicted_output = (2.0 / batch_size) * error
        grad_weights_2 = relu_output.T @ grad_predicted_output
        grad_bias_2 = np.sum(grad_predicted_output, axis=0)
        grad_relu_output = grad_predicted_output @ weights_2.T
        grad_dense_1_output = grad_relu_output * relu_grad(dense_1_output)
        grad_weights_1 = x_batch.T @ grad_dense_1_output
        grad_bias_1 = np.sum(grad_dense_1_output, axis=0)

        weights_1 -= learning_rate * grad_weights_1
        bias_1 -= learning_rate * grad_bias_1
        weights_2 -= learning_rate * grad_weights_2
        bias_2 -= learning_rate * grad_bias_2

        input_batch_history.append(x_batch.copy())
        target_output_batch_history.append(target_batch.copy())
        predicted_output_batch_history.append(predicted_output.copy())
        loss_batch_history.append(loss)

final_predicted_output = relu(x_input @ weights_1 + bias_1) @ weights_2 + bias_2
total_mse = np.mean((final_predicted_output - target_output) ** 2)

input_batch_history = np.array(input_batch_history, dtype=np.float64)
target_output_batch_history = np.array(target_output_batch_history, dtype=np.float64)
predicted_output_batch_history = np.array(predicted_output_batch_history, dtype=np.float64)
loss_batch_history = np.array(loss_batch_history, dtype=np.float64)

files = {
    "input": write_bin(output_dir, "Cubic_ReluDense_Test_1_input_data.bin", x_input),
    "output": write_bin(output_dir, "Cubic_ReluDense_Test_1_output_data.bin", target_output),
    "initial_weights_1": write_bin(output_dir, "Cubic_ReluDense_Test_1_initial_weights_1.bin", initial_weights_1),
    "initial_bias_1": write_bin(output_dir, "Cubic_ReluDense_Test_1_initial_bias_1.bin", initial_bias_1),
    "initial_weights_2": write_bin(output_dir, "Cubic_ReluDense_Test_1_initial_weights_2.bin", initial_weights_2),
    "initial_bias_2": write_bin(output_dir, "Cubic_ReluDense_Test_1_initial_bias_2.bin", initial_bias_2),
    "predicted_batch_output": write_bin(output_dir, "Cubic_ReluDense_Test_1_predicted_batch_output.bin", predicted_output_batch_history),
    "batch_loss_history": write_bin(output_dir, "Cubic_ReluDense_Test_1_batch_loss_history.bin", loss_batch_history),
}

print("Cubic dense(16) -> relu -> dense training reference data generated")
print(f"input: {x_input.shape}, target_output: {target_output.shape}")
print(f"batch histories: input {input_batch_history.shape}, predicted_output {predicted_output_batch_history.shape}")
print(f"loss history: {loss_batch_history.shape}")
print(f"total mse: {total_mse:.10f}")
for name, path in files.items():
    print(f"{name}: {path}")
# Out:
# Cubic dense(16) -> relu -> dense training reference data generated
# input: (1024, 1), target_output: (1024, 1)
# batch histories: input (4000, 256, 1), predicted_output (4000, 256, 1)
# loss history: (4000,)
# total mse: 0.0189800380
# input: ../data/Cubic_ReluDense_Test_1_input_data.bin
# output: ../data/Cubic_ReluDense_Test_1_output_data.bin
# predicted_batch_output: ../data/Cubic_ReluDense_Test_1_predicted_batch_output.bin
# batch_loss_history: ../data/Cubic_ReluDense_Test_1_batch_loss_history.bin

# %% [markdown]
# ## Sin wave fitting y = sin(x), i.e -pi <= x <= pi

# %%
# Sin wave fitting y = sin(x), -pi <= x <= pi
import numpy as np
from pathlib import Path


def relu(x):
    return np.maximum(x, 0.0)


def relu_grad(x):
    return (x > 0.0).astype(np.float64)


def write_bin(output_dir, filename, values):
    path = output_dir / filename
    np.asarray(values, dtype=np.float64).tofile(path)
    return path


rng = np.random.default_rng(8192)
output_dir = Path("../data")

sample_size = 1025
input_features = 1
hidden_units_1 = 16
hidden_units_2 = 16
output_features = 1
batch_size = 512
epochs = 1000
learning_rate = 0.01

# Data set: 1025 scalar inputs and their sine targets.
x_input = np.linspace(-np.pi, np.pi, sample_size, dtype=np.float64).reshape(sample_size, input_features)
target_output = np.sin(x_input)

# Model architecture: dense(16) -> relu() -> dense(16) -> relu() -> dense(1).
weights_1 = rng.normal(loc=0.0, scale=0.25, size=(input_features, hidden_units_1))
bias_1 = np.zeros(hidden_units_1, dtype=np.float64)
weights_2 = rng.normal(loc=0.0, scale=0.25, size=(hidden_units_1, hidden_units_2))
bias_2 = np.zeros(hidden_units_2, dtype=np.float64)
weights_3 = rng.normal(loc=0.0, scale=0.25, size=(hidden_units_2, output_features))
bias_3 = np.zeros(output_features, dtype=np.float64)

initial_weights_1 = weights_1.copy()
initial_bias_1 = bias_1.copy()
initial_weights_2 = weights_2.copy()
initial_bias_2 = bias_2.copy()
initial_weights_3 = weights_3.copy()
initial_bias_3 = bias_3.copy()

num_batches = sample_size // batch_size
train_sample_size = num_batches * batch_size
epoch_loss_history = []

for epoch in range(epochs):
    batch_losses = []
    for batch_index in range(num_batches):
        start = batch_index * batch_size
        end = start + batch_size

        x_batch = x_input[start:end]
        target_batch = target_output[start:end]

        dense_1_output = x_batch @ weights_1 + bias_1
        relu_1_output = relu(dense_1_output)
        dense_2_output = relu_1_output @ weights_2 + bias_2
        relu_2_output = relu(dense_2_output)
        predicted_output = relu_2_output @ weights_3 + bias_3

        error = predicted_output - target_batch
        batch_losses.append(np.mean(error ** 2))
        grad_predicted_output = (2.0 / batch_size) * error

        grad_weights_3 = relu_2_output.T @ grad_predicted_output
        grad_bias_3 = np.sum(grad_predicted_output, axis=0)
        grad_relu_2_output = grad_predicted_output @ weights_3.T
        grad_dense_2_output = grad_relu_2_output * relu_grad(dense_2_output)

        grad_weights_2 = relu_1_output.T @ grad_dense_2_output
        grad_bias_2 = np.sum(grad_dense_2_output, axis=0)
        grad_relu_1_output = grad_dense_2_output @ weights_2.T
        grad_dense_1_output = grad_relu_1_output * relu_grad(dense_1_output)

        grad_weights_1 = x_batch.T @ grad_dense_1_output
        grad_bias_1 = np.sum(grad_dense_1_output, axis=0)

        weights_1 -= learning_rate * grad_weights_1
        bias_1 -= learning_rate * grad_bias_1
        weights_2 -= learning_rate * grad_weights_2
        bias_2 -= learning_rate * grad_bias_2
        weights_3 -= learning_rate * grad_weights_3
        bias_3 -= learning_rate * grad_bias_3

    epoch_loss_history.append(np.mean(batch_losses))

last_epoch_mse = epoch_loss_history[-1]

files = {
    "input": write_bin(output_dir, "Sin_ReluDense_Test_1_input_data.bin", x_input),
    "target_output": write_bin(output_dir, "Sin_ReluDense_Test_1_target_output_data.bin", target_output),
    "initial_weights_1": write_bin(output_dir, "Sin_ReluDense_Test_1_initial_weights_1.bin", initial_weights_1),
    "initial_bias_1": write_bin(output_dir, "Sin_ReluDense_Test_1_initial_bias_1.bin", initial_bias_1),
    "initial_weights_2": write_bin(output_dir, "Sin_ReluDense_Test_1_initial_weights_2.bin", initial_weights_2),
    "initial_bias_2": write_bin(output_dir, "Sin_ReluDense_Test_1_initial_bias_2.bin", initial_bias_2),
    "initial_weights_3": write_bin(output_dir, "Sin_ReluDense_Test_1_initial_weights_3.bin", initial_weights_3),
    "initial_bias_3": write_bin(output_dir, "Sin_ReluDense_Test_1_initial_bias_3.bin", initial_bias_3),
    "last_epoch_mse": write_bin(output_dir, "Sin_ReluDense_Test_1_last_epoch_mse.bin", np.array([last_epoch_mse])),
}

print("Sin dense(16) -> relu -> dense(16) -> relu -> dense training reference data generated")
print(f"input: {x_input.shape}, target_output: {target_output.shape}")
print(f"dataset_size: {sample_size}, batch_size: {batch_size}, epochs: {epochs}, trained_samples_per_epoch: {train_sample_size}")
print(f"last epoch mse: {last_epoch_mse:.10f}")
for name, path in files.items():
    print(f"{name}: {path}")
